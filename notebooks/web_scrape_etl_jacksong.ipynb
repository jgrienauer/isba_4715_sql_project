# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)

# %%
# !pip install sqlalchemy mysqlclient
# Out:
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.10/dist-packages (2.0.29)
# Collecting mysqlclient
#   Downloading mysqlclient-2.2.4.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 2.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from sqlalchemy) (3.0.3)
# Building wheels for collected packages: mysqlclient
#   Building wheel for mysqlclient (pyproject.toml) ... done
#   Created wheel for mysqlclient: filename=mysqlclient-2.2.4-cp310-cp310-linux_x86_64.whl size=124727 sha256=f67daab44dbade019a849c772373195aec287eca794f4b93716ca54cc82be77c
#   Stored in directory: /root/.cache/pip/wheels/ac/96/ac/2a4d8cb58a4d95de1dffc3f8b0ea42e0e5b63ab97640edbda3
# Successfully built mysqlclient
# Installing collected packages: mysqlclient
# Successfully installed mysqlclient-2.2.4

# %%
import requests

from bs4 import BeautifulSoup

import pandas as pd

from sqlalchemy import create_engine

# %%
#urls for player name, team, contract length
#catchers url
url1 = 'https://www.spotrac.com/mlb/rankings/_/year/2024/position/c'

#1B url
url2 = 'https://www.spotrac.com/mlb/rankings/_/year/2024/position/1b'

#2B url
url3 = 'https://www.spotrac.com/mlb/rankings/_/year/2024/position/2b'

#3b url
url4 = 'https://www.spotrac.com/mlb/rankings/_/year/2024/position/3b'

#SS url
url5 = 'https://www.spotrac.com/mlb/rankings/_/year/2024/position/ss'

#RF url
url6 = 'https://www.spotrac.com/mlb/rankings/_/year/2024/position/rf'

#CF url
url7 = 'https://www.spotrac.com/mlb/rankings/_/year/2024/position/cf'

#LF url
url8 = 'https://www.spotrac.com/mlb/rankings/_/year/2024/position/lf'

#pitchers url
url9 = 'https://www.spotrac.com/mlb/rankings/_/year/2024/position/p'

#dh url
url10 = 'https://www.spotrac.com/mlb/rankings/_/year/2024/position/dh'

extended_request = requests.get(url1)

# %%
extended_request
# Out:
# <Response [200]>

# %%
extended_request.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n  \n\t<head>\n\t<meta charset="utf-8">\n\t<title>2024 MLB Rankings</title>\n\t\n    <!-- SEO Meta Tags-->\n\t<meta name="description" content="Listing the top salaries, cap hits, cash, earnings, contracts, and bonuses, for all active MLB players.">\n\t<meta name="keywords" content="2024, MLB, rankings, player, position">\n\t<meta name="author" content="Spotrac">\n\t\n    <!-- Viewport-->\n\t<meta name="viewport" content="width=device-width, initial-scale=1">\n    \n    <meta property="fb:app_id" content="206107179423868" />\n    <meta property="fb:admins" content="513540967"/>\n    <meta property="og:site_name" content="spotrac.com" />\n    <meta property="og:url" content="https://www.spotrac.com/mlb/rankings/_/year/2024/position/c" />\n    <meta property="og:title" content="2024 MLB Rankings"/>\n        <meta property="og:description" content="Listing the top salaries, cap hits, cash, earnings, contracts, and bonuses, for all active MLB players." />\n        <meta property="og:image" content="https://www.spotrac.com/public/img/logo-tall-white.png"/>\n        <meta property="og:type" content="website" />\n    <meta name="twitter:site" content="spotrac.com" />\n    <meta name="twitter:url" content="https://www.spotrac.com/mlb/rankings/_/year/2024/position/c" />\n    <meta name="twitter:title" content="2024 MLB Rankings"/>\n        <meta property="twitter:description" content="Listing the top salaries, cap hits, cash, earnings, contracts, and bonuses, for all active MLB players." />\n        <meta name="twitter:image" content="https://www.spotrac.com/public/img/logo-tall-white.png"/>\n    <meta name="twitter:card" content="summary">\n    <meta name="title" content="2024 MLB Rankings"/>    \n    \n    \n    <link rel="canonical" href="https://www.spotrac.com/mlb/rankings/_/year/2024/position/c" />\t\n    <!-- Favicon and Touch Icons-->\n    <link rel="icon" type="image/x-icon" href="https://www.spotrac.com/public/img/favicon.ico">\n\t<link rel="apple-touch-icon" sizes="180x180" href="https://www.spotrac.com/public/img/favicon.ico">\n\t<link rel="icon" type="image/png" sizes="32x32" href="https://www.spotrac.com/public/img/favicon.ico">\n\t<link rel="icon" type="image/png" sizes="16x16" href="https://www.spotrac.com/public/img/favicon.ico">\n\t<link rel="mask-icon" color="#fe6a6a" href="https://www.spotrac.com/public/img/favicon.ico">\n\t<meta name="msapplication-TileColor" content="#ffffff">\n\t<meta name="theme-color" content="#ffffff">\n\t\n\t<!-- Vendor Styles including: Font Icons, Plugins, etc.-->\n\t<link rel="stylesheet" media="screen" href="https://www.spotrac.com/public/vendor/simplebar/dist/simplebar.min.css"/>\n\t<link rel="stylesheet" media="screen" href="https://www.spotrac.com/public/vendor/tiny-slider/dist/tiny-slider.css"/>\n\t<link href=\'https://www.spotrac.com/public/fonts/roboto.css\' rel=\'stylesheet\' type=\'text/css\'>\n\t\t\n\t<!-- Main Theme Styles + Bootstrap-->\n\t<link rel="stylesheet" media="screen" href="https://www.spotrac.com/public/css/theme.css">\n\t<link rel="stylesheet" media="screen" href="https://www.spotrac.com/public/css/custom-theme.css">\n\t<link rel="stylesheet" media="screen" href="https://www.spotrac.com/public/css/custom-theme-big.css">\n\t<link rel="stylesheet" media="screen" href="https://www.spotrac.com/public/css/custom-nav.css">\n\t<link rel="stylesheet" media="screen" href="https://www.spotrac.com/public/css/custom-table.css">\n\t<link rel="stylesheet" media="screen" href="https://www.spotrac.com/public/css/custom-filter.css">\n\t<link rel="stylesheet" media="screen" href="https://www.spotrac.com/public/css/custom-colors.css">\n\n\n    <script src="https://www.spotrac.com/public/vendor/jquery/jquery-3.6.1.min.js"></script>\n\n    <!-- jQuery-->\n        <script src="https://www.spotrac.com/public/vendor/kit-73b9c60b16-web/js/all.min.js" crossorigin="anonymous"></script>\n    \n    \n    <!-- Google Recaptcha -->\n    <script src=\'https://www. ...

# %%
soup = BeautifulSoup(extended_request.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    2024 MLB Rankings
#   </title>
#   <!-- SEO Meta Tags-->
#   <meta content="Listing the top salaries, cap hits, cash, earnings, contracts, and bonuses, for all active MLB players." name="description"/>
#   <meta content="2024, MLB, rankings, player, position" name="keywords"/>
#   <meta content="Spotrac" name="author"/>
#   <!-- Viewport-->
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="206107179423868" property="fb:app_id">
#    <meta content="513540967" property="fb:admins">
#     <meta content="spotrac.com" property="og:site_name">
#      <meta content="https://www.spotrac.com/mlb/rankings/_/year/2024/position/c" property="og:url">
#       <meta content="2024 MLB Rankings" property="og:title">
#        <meta content="Listing the top salaries, cap hits, cash, earnings, contracts, and bonuses, for all active MLB players." property="og:description"/>
#        <meta content="https://www.spotrac.com/public/img/logo-tall-white.png" property="og:image"/>
#        <meta content="website" property="og:type"/>
#        <meta content="spotrac.com" name="twitter:site"/>
#        <meta content="https://www.spotrac.com/mlb/rankings/_/year/2024/position/c" name="twitter:url"/>
#        <meta content="2024 MLB Rankings" name="twitter:title"/>
#        <meta content="Listing the top salaries, cap hits, cash, earnings, contracts, and bonuses, for all active MLB players." property="twitter:description"/>
#        <meta content="https://www.spotrac.com/public/img/logo-tall-white.png" name="twitter:image"/>
#        <meta content="summary" name="twitter:card"/>
#        <meta content="2024 MLB Rankings" name="title">
#         <link href="https://www.spotrac.com/mlb/rankings/_/year/2024/position/c" rel="canonical"/>
#         <!-- Favicon and Touch Icons-->
#         <link href="https://www.spotrac.com/public/img/favicon.ico" rel="icon" type="image/x-icon"/>
#         <link href="https://www.spotrac.com/public/img/favicon.ico" rel="apple-touch-icon" sizes="180x180"/>
#         <link href="https://www.spotrac.com/public/img/favicon.ico" rel="icon" sizes="32x32" type="image/png"/>
#         <link href="https://www.spotrac.com/public/img/favicon.ico" rel="icon" sizes="16x16" type="image/png"/>
#         <link color="#fe6a6a" href="https://www.spotrac.com/public/img/favicon.ico" rel="mask-icon"/>
#         <meta content="#ffffff" name="msapplication-TileColor"/>
#         <meta content="#ffffff" name="theme-color"/>
#         <!-- Vendor Styles including: Font Icons, Plugins, etc.-->
#         <link href="https://www.spotrac.com/public/vendor/simplebar/dist/simplebar.min.css" media="screen" rel="stylesheet">
#          <link href="https://www.spotrac.com/public/vendor/tiny-slider/dist/tiny-slider.css" media="screen" rel="stylesheet">
#           <link href="https://www.spotrac.com/public/fonts/roboto.css" rel="stylesheet" type="text/css"/>
#           <!-- Main Theme Styles + Bootstrap-->
#           <link href="https://www.spotrac.com/public/css/theme.css" media="screen" rel="stylesheet"/>
#           <link href="https://www.spotrac.com/public/css/custom-theme.css" media="screen" rel="stylesheet"/>
#           <link href="https://www.spotrac.com/public/css/custom-theme-big.css" media="screen" rel="stylesheet"/>
#           <link href="https://www.spotrac.com/public/css/custom-nav.css" media="screen" rel="stylesheet"/>
#           <link href="https://www.spotrac.com/public/css/custom-table.css" media="screen" rel="stylesheet"/>
#           <link href="https://www.spotrac.com/public/css/custom-filter.css" media="screen" rel="stylesheet"/>
#           <link href="https://www.spotrac.com/public/css/custom-colors.css" media="screen" rel="stylesheet"/>
#           <script src="https://www.spotrac.com/public/vendor/jquery/jquery-3.6.1.min.js">
#           </script>
#           <!-- jQuery-->
#           <script crossorigin="anonymous" src="https://www.spotrac.com/public/vendor/kit-73b9c60b16-web/js/all.min.js">
#           </script>
#           <!-- Google Recaptcha -->
#           <script src="https://www.google.com/recaptcha/api.js">
#           </script>
#           <!-- Google Analytics: GA4 -->
#           <!-- Global site tag (gtag.js) - Google Analytics -->
#           <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-3ZZTGEXZ3B">
#           </script>
#           <script>
#            window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-3ZZTGEXZ3B');
#           </script>
#           <!-- BEGIN THM AUTO CODE -->
#           <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#           </script>
#           <script type="text/javascript">
#            var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     googletag.cmd.push(function() {
#       googletag.pubads().disableInitialLoad(); googletag.pubads().enableSingleRequest();
#     });
#     var _hbopts = { alias: '/', type: 'banner' };
#     var _hbwrap = _hbwrap || [];
#     (function() {
#       var hbldr = function (url, resolution, cachebuster, millis, referrer) {
#         var s = document.createElement('script'); s.type = 'text/javascript';
#         s.async = true; s.src = 'https://' + url + '&resolution=' + resolution +
#           '&random=' + cachebuster + '&millis=' + millis + '&referrer=' + referrer;
#         var x = document.getElementsByTagName('script')[0];
#         x.parentNode.insertBefore(s, x);
#       };
#       hbldr(
#         'tradecore.tradehouse.media/servlet/hbwrap?stack=11',
#         (window.innerWidth||screen.width)+'x'+(window.innerHeight||screen.height),
#         Math.floor(89999999*Math.random()+10000000), new Date().getTime(), encodeURIComponent(
#           (window!=top&&window.location.ancestorOrigins)?
#             window.location.ancestorOrigins[window.location.ancestorOrigins.length-1]:document.location
#         )
#       );
#     })();
#           </script>
#           <!-- END THM AUTO CODE -->
#           <!-- Mailchimp-->
#           <!-- Page specific css-->
#           <style>
#            .stat-wrapper h2 {
#     line-height: 100%;
#     color: #1c1c1c;
#     font-weight: 600;
#     padding-bottom: 5px;
#     margin: 0px;
#     margin-bottom: 0px;
#     text-transform: uppercase;
#
# }
# .stat-header {line-height: 100%;background:#eee;}
# .stat-header a {color:#006699;}
# .stat-wrapper{ padding:10px; min-height:200px;}
# .stat-wrapper ol { margin:0px;padding:0px;}
# .stat-wrapper ol li::before {
#     color: red !important;
#     font-weight: bold !important;
# }
# .stat-wrapper li { font-weight:600;clear:both; width: 100%;  margin-left: 0; padding: 4px 0px; line-height: 125%;text-indent: -15px;margin-left: 20px;padding-right:25px;}
#
#
# .stat-wrapper li .name{ float: left; width: 60%; padding-left:15px; font-size: 12px; font-weight: normal; }
# .stat-wrapper li .team-position{ font-size: 10px; font-weight: normal; color:#ADADAD; display: inline; margin-left: 8px; }
# .stat-wrapper li .name a{  color: #cc3333; }
# .stat-wrapper li .value{ float: right; width: 40%; text-align: right; font-size: 12px; font-weight: normal;}
# .stat-wrapper .more{ color: #006699; float:right }
#
# .stat-wrapper2 li .name{ float: left; width: 60%; padding-left:8px; font-size: 12px; font-weight: normal; }
#
# 	@media (max-width: 767px) {
#
#         .stat-wrapper {min-height:auto !important;margin-bottom:1rem !important;padding:10px !important}
#
#     }
#           </style>
#          </link>
#         </link>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <!-- body -->
#  <body class="handheld-toolbar-enabled">
#   <!-- main -->
#   <main class="page-wrapper">
#    <!-- Sign in / sign up modal-->
#    <div class="modal fade" id="signin-modal" role="dialog" tabindex="-1">
#     <div class="modal-dialog" role="document">
#      <div class="modal-content">
#       <div class="modal-header bg-secondary">
#        <ul class="nav nav-tabs card-header-tabs" role="tablist">
#         <li class="nav-item">
#          <a aria-selected="true" class="nav-link fw-medium active" data-bs-toggle="tab" href="#signin-tab" role="tab">
#           <i class="ci-unlocked me-2 mt-n1">
#           </i>
#           Sign in
#          </a>
#         </li>
#         <li class="nav-item">
#          <a aria-selected="false" class="nav-link fw-medium" data-bs-toggle="tab" href="#signup-tab" role="tab">
#           <i class="ci-user me-2 mt-n1">
#           </i>
#           Sign up
#          </a>
#         </li>
#        </ul>
#        <button aria-label="Close" class="btn-close" data-bs-dismiss="modal" type="button">
#        </button>
#       </div>
#       <div class="modal-body tab-content py-4">
#        <form action="https://www.spotrac.com/login/submit" autocomplete="off" class="needs-validation tab-pane fade show active" id="signin-tab" method="post" novalidate="">
#         <input id="goto1" name="goto" type="hidden" value="https://www.spotrac.com/mlb/rankings/_/year/2024/position/c"/>
#         <div class="mb-3">
#          <label class="form-label" for="si-email">
#           Email address
#          </label>
#          <input class="form-control form-control-sm" id="si-email" name="email" placeholder="johndoe@example.com" required="" type="email"/>
#          <div class="invalid-feedback">
#           Please provide a valid email address.
#          </div>
#         </div>
#         <div class="mb-3">
#          <label class="form-label" for="si-password">
#           Password
#          </label>
#          <div class="password-toggle">
#           <input class="form-control form-control-sm" id="si-password" name="password" required="" type="password"/>
#           <label aria-label="Show/hide password" class="password-toggle-btn">
#            <input class="password-toggle-check" type="checkbox"/>
#            <span class="password-toggle-indicator">
#            </span>
#           </label>
#          </div>
#         </div>
#         <div class="mb-3 d-flex flex-wrap justify-content-between">
#          <div class="form-check mb-2">
#          </div>
#          <a class="fs-sm" href="https://www.spotrac.com/login/forgot">
#           Forgot password?
#          </a>
#         </div>
#         <button class="btn btn-navy btn-shadow d-block w-100" type="submit">
#          Sign in
#         </button>
#        </form>
#        <form action="https://www.spotrac.com/register/submit" autocomplete="off" class="needs-validation tab-pane fade" id="signup-tab" method="post" novalidate="">
#         <input id="goto2" name="goto" type="hidden" value="https://www.spotrac.com/mlb/rankings/_/year/2024/position/c">
#          <div class="mb-3 fw-bold">
#           Why sign up for Spotrac Premium?!
#           <ul class="ms-0 ps-3 fw-normal">
#            <li class="float-start w-50">
#             Ad-FREE Experience
#            </li>
#            <li class="float-start w-50">
#             Historical Contract Information
#            </li>
#            <li class="float-start w-50">
#             Historical Team Financials
#            </li>
#            <li class="float-start w-50">
#             Advanced Data Portal
#            </li>
#           </ul>
#          </div>
#          <br/>
#          <div class="mt-3 mb-2 mb-3 fw-bold text-navy">
#           Just $30 per year (recurring)!
#          </div>
#          <div class="mb-3">
#           <label class="form-label" for="su-first-name">
#            First Name
#           </label>
#           <input class="form-control form-control-sm" id="su-first-name" name="first_name" placeholder="John" required="" type="text"/>
#           <div class="invalid-feedback">
#            Please fill in your first name.
#           </div>
#          </div>
#          <div class="mb-3">
#           <label class="form-label" for="su-last-name">
#            Last Name
#           </label>
#           <input class="form-control form-control-sm" id="su-last-name" name="last_name" placeholder=" Doe" required="" type="text"/>
#           <div class="invalid-feedback">
#            Please fill in your last name.
#           </div>
#          </div>
#          <div class="mb-3">
#           <label for="su-email">
#            Email address
#           </label>
#           <input class="form-control form-control-sm" id="su-email" name="email" placeholder="johndoe@example.com" required="" type="email"/>
#           <div class="invalid-feedback">
#            Please provide a valid email address.
#           </div>
#          </div>
#          <div class="mb-3">
#           <label class="form-label" for="su-password">
#            Password
#           </label>
#           <div class="password-toggle">
#            <input class="form-control form-control-sm" id="su-password" name="password" required="" type="password"/>
#            <label aria-label="Show/hide password" class="password-toggle-btn">
#             <input class="password-toggle-check" type="checkbox"/>
#             <span class="password-toggle-indicator">
#             </span>
#            </label>
#           </div>
#          </div>
#          <div class="mb-3">
#           <div class="g-recaptcha" data-sitekey="6LehNE4UAAAAAFK4dftCLAbKcJqwS9tCOlvr94o6">
#           </div>
#          </div>
#          <button class="btn btn-navy btn-shadow d-block w-100" name="submit" type="submit">
#           Sign up
#          </button>
#         </input>
#        </form>
#       </div>
#      </div>
#     </div>
#    </div>
#    <header class="navbar-sticky shadow-sm" id="nav-header">
#     <!-- Remove "navbar-sticky" class to make navigation bar scrollable with the page.-->
#     <div class="bg-light">
#      <div class="navbar navbar-expand-lg navbar-light p-0">
#       <div class="container">
#        <a class="navbar-brand d-none d-sm-block flex-shrink-0" href="https://www.spotrac.com" tabindex="-1">
#         <img alt="spotrac" src="https://www.spotrac.com/public/img/logo.png" width="225"/>
#        </a>
#        <a class="navbar-brand d-sm-none flex-shrink-0 me-2" href="https://www.spotrac.com" tabindex="-1">
#         <img alt="spotrac" src="https://www.spotrac.com/public/img/logo.png" width="100"/>
#        </a>
#        <form action="https://www.spotrac.com/search" method="get" style="display:contents;">
#         <div class="input-group d-none d-lg-flex mx-4">
#          <input class="form-control rounded-end pe-5" name="q" placeholder="Search for a Player" tabindex="-1" type="text"/>
#          <i class="ci-search position-absolute top-50 end-0 translate-middle-y text-muted fs-base me-3">
#          </i>
#         </div>
#        </form>
#        <div class="navbar-toolbar d-flex flex-shrink-0 align-items-center">
#         <button class="navbar-toggler" data-bs-target="#navbarCollapse" data-bs-toggle="collapse" type="button">
#          <span class="navbar-toggler-icon">
#          </span>
#         </button>
#         <a class="navbar-tool navbar-stuck-toggler" href="#">
#          <span class="navbar-tool-tooltip">
#           Expand menu
#          </span>
#         </a>
#         <a class="navbar-tool ms-1 ms-lg-2 me-n1 me-lg-3 text-body d-none d-lg-block" data-bs-toggle="" href="https://twitter.com/spotrac" tabindex="-1" target="_blank">
#          <i class="navbar-tool-icon fa-brands fa-x-twitter">
#          </i>
#         </a>
#         <a class="navbar-tool ms-1 ms-lg-2 me-n1 me-lg-3 text-body d-none d-lg-block" data-bs-toggle="" href="https://www.youtube.com/c/TheSpotracPodcast" tabindex="-1" target="_blank">
#          <i class="navbar-tool-icon fa-brands fa-youtube">
#          </i>
#         </a>
#         <a class="navbar-tool ms-1 ms-lg-2 me-n1 me-lg-3 text-body d-none d-lg-block" data-bs-toggle="" href="https://www.facebook.com/spotrac/" tabindex="-1" target="_blank">
#          <i class="navbar-tool-icon fa-brands fa-facebook-f">
#          </i>
#         </a>
#         <a class="navbar-tool ms-1 ms-lg-2 me-n1 me-lg-3 text-body d-none d-lg-block" data-bs-toggle="" href="https://www.instagram.com/spotrac/" tabindex="-1" target="_blank">
#          <i class="navbar-tool-icon fa-brands fa-instagram">
#          </i>
#         </a>
#         <a class="navbar-tool ms-1 ms-lg-0 me-n1 me-lg-0 d-none d-md-inline-flex" data-bs-toggle="modal" href="#signin-modal" tabindex="-1">
#          <div class="navbar-tool-icon-box">
#           <i class="navbar-tool-icon ci-user">
#           </i>
#          </div>
#         </a>
#         <a class="navbar-tool ms-1 ms-lg-0 me-n1 me-lg-0 d-none d-md-inline-flex" data-bs-toggle="modal" href="#signin-modal" tabindex="-1">
#          <div class="navbar-tool-text ms-n3">
#           <small>
#            Hello, Sign in
#           </small>
#           Premium
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="navbar navbar-expand-lg navbar-mobile navbar-level1 navbar-light mt-0 pt-0 pb-0" style="border-top:1px solid #dae1e7">
#       <div class="container">
#        <div class="collapse navbar-collapse" id="navbarCollapse">
#         <!-- Search-->
#         <form action="https://www.spotrac.com/search" method="get" style="display:contents;">
#          <div class="input-group d-lg-none my-3">
#           <i class="ci-search position-absolute top-50 start-0 translate-middle-y text-muted fs-base ms-3">
#           </i>
#           <input class="form-control rounded-start" name="q" placeholder="Search a Player or Team" tabindex="-1" type="text"/>
#          </div>
#         </form>
#         <ul class="navbar-nav navbar-mega-nav">
#          <li class="nav-item dropdown d-block d-sm-none">
#           <a class="nav-link dropdown-toggle py-0" data-bs-toggle="dropdown" href="#" tabindex="-1">
#            PREMIUM
#           </a>
#           <div class="dropdown-menu p-0">
#            <div class="d-flex flex-wrap flex-sm-nowrap px-2">
#             <div class="mega-dropdown-column pt-1 pt-lg-4 pb-0 px-2 px-lg-3">
#              <div class="widget widget-links mb-4">
#               <ul class="widget-list">
#                <li class="widget-list-item">
#                 <a class="widget-list-link" data-bs-toggle="modal" href="#signin-modal">
#                  My Account
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/logout">
#                  Logout
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li class="nav-item">
#           <a class="nav-link py-0" data-bs-toggle="" href="https://www.spotrac.com/" tabindex="-1">
#            HOME
#           </a>
#          </li>
#          <li class="nav-item dropdown">
#           <a class="nav-link dropdown-toggle py-0" data-bs-toggle="dropdown" href="https://www.spotrac.com/nfl" tabindex="-1">
#            NFL
#           </a>
#           <div class="dropdown-menu p-0">
#            <div class="d-flex flex-wrap flex-sm-nowrap px-2">
#             <div class="mega-dropdown-column pt-1 pt-lg-4 pb-4 px-2 px-lg-3">
#              <div class="widget widget-links mb-4">
#               <a class="widget-list-link" href="https://www.spotrac.com/nfl">
#                <h6 class="fs-base mb-3">
#                 Home
#                </h6>
#               </a>
#              </div>
#              <div class="widget widget-links mb-4">
#               <a class="widget-list-link" href="https://www.spotrac.com/nfl/teams">
#                <h6 class="fs-base mb-3">
#                 Teams
#                </h6>
#               </a>
#              </div>
#              <div class="widget widget-links mb-4">
#               <h6 class="fs-base mb-3">
#                Popular Pages
#               </h6>
#               <ul class="widget-list">
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nfl/cap">
#                  Team Cap
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nfl/rankings">
#                  Rankings
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nfl/contracts">
#                  Contracts
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nfl/free-agents">
#                  Free Agents
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nfl/draft">
#                  Draft
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div class="widget widget-links mb-4">
#               <h6 class="fs-base mb-3">
#                Transactions
#               </h6>
#               <ul class="widget-list">
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nfl/transactions">
#                  All Transactions
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nfl/transactions/trade">
#                  Trades
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nfl/transactions/_/type/signed-extended">
#                  Extensions
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nfl/fines-suspensions">
#                  Fines &amp; Suspensions
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div class="widget widget-links mb-4">
#               <h6 class="fs-base mb-3">
#                Trending Players
#               </h6>
#               <ul class="widget-list">
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/redirect/player/12344">
#                  Travis Kelce
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/redirect/player/18952">
#                  Ezekiel Elliott
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/redirect/player/9915">
#                  Kirk Cousins
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/redirect/player/21751">
#                  Patrick Mahomes
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/redirect/player/72418">
#                  Christian Barmore
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <div class="mega-dropdown-column-4 pt-1 pt-lg-4 pb-4 px-2 px-lg-3 w-100">
#              <div class="row p-0">
#               <div class="col-md-3 col-sm-6 mb-3">
#                <h6 class="fs-base mb-3">
#                 AFC East
#                </h6>
#                <ul class="widget-list">
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/buffalo-bills/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/buf.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    BUF Bills
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Buffalo Bills
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/miami-dolphins/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/mia.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    MIA Dolphins
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Miami Dolphins
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/new-england-patriots/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/ne.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    NE Patriots
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    New England Patriots
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/new-york-jets/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/nyj.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    NYJ Jets
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    New York Jets
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#               <div class="col-md-3 col-sm-6 mb-3">
#                <h6 class="fs-base mb-3">
#                 AFC North
#                </h6>
#                <ul class="widget-list">
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/baltimore-ravens/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/bal.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    BAL Ravens
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Baltimore Ravens
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/cincinnati-bengals/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/cin.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    CIN Bengals
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Cincinnati Bengals
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/cleveland-browns/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/cle1.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    CLE Browns
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Cleveland Browns
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/pittsburgh-steelers/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/pit.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    PIT Steelers
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Pittsburgh Steelers
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#               <div class="col-md-3 col-sm-6 mb-3">
#                <h6 class="fs-base mb-3">
#                 AFC South
#                </h6>
#                <ul class="widget-list">
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/houston-texans/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/hou.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    HOU Texans
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Houston Texans
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/indianapolis-colts/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/ind1.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    IND Colts
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Indianapolis Colts
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/jacksonville-jaguars/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/jax.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    JAC Jaguars
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Jacksonville Jaguars
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/tennessee-titans/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/ten.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    TEN Titans
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Tennessee Titans
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#               <div class="col-md-3 col-sm-6 mb-3">
#                <h6 class="fs-base mb-3">
#                 AFC West
#                </h6>
#                <ul class="widget-list">
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/denver-broncos/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/den3.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    DEN Broncos
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Denver Broncos
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/kansas-city-chiefs/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/kc1.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    KC Chiefs
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Kansas City Chiefs
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/las-vegas-raiders/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/lv.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    LV Raiders
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Las Vegas Raiders
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/los-angeles-chargers/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/lac.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    LAC Chargers
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Los Angeles Chargers
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#              <div class="row mt-5">
#               <div class="col-md-3 col-sm-6 mb-3">
#                <h6 class="fs-base mb-3">
#                 NFC East
#                </h6>
#                <ul class="widget-list">
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/dallas-cowboys/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/dal.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    DAL Cowboys
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Dallas Cowboys
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/new-york-giants/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/nyg.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    NYG Giants
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    New York Giants
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/philadelphia-eagles/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/phi.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    PHI Eagles
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Philadelphia Eagles
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/washington-commanders/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/was_2022.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    WAS Commanders
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Washington Commanders
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#               <div class="col-md-3 col-sm-6 mb-3">
#                <h6 class="fs-base mb-3">
#                 NFC North
#                </h6>
#                <ul class="widget-list">
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/chicago-bears/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/chi.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    CHI Bears
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Chicago Bears
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/detroit-lions/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/det.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    DET Lions
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Detroit Lions
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/green-bay-packers/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/gb.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    GB Packers
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Green Bay Packers
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/minnesota-vikings/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/min.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    MIN Vikings
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Minnesota Vikings
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#               <div class="col-md-3 col-sm-6 mb-3">
#                <h6 class="fs-base mb-3">
#                 NFC South
#                </h6>
#                <ul class="widget-list">
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/atlanta-falcons/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/atl2.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    ATL Falcons
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Atlanta Falcons
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/carolina-panthers/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/car.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    CAR Panthers
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Carolina Panthers
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/new-orleans-saints/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/no.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    NO Saints
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    New Orleans Saints
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/tampa-bay-buccaneers/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/tb.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    TB Buccaneers
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Tampa Bay Buccaneers
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#               <div class="col-md-3 col-sm-6 mb-3">
#                <h6 class="fs-base mb-3">
#                 NFC West
#                </h6>
#                <ul class="widget-list">
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/arizona-cardinals/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/ari.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    ARI Cardinals
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Arizona Cardinals
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/los-angeles-rams/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/lar.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    LAR Rams
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Los Angeles Rams
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/san-francisco-49ers/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/sf.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    SF 49ers
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    San Francisco 49ers
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/seattle-seahawks/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/sea1.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    SEA Seahawks
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Seattle Seahawks
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li class="nav-item dropdown">
#           <a class="nav-link dropdown-toggle py-0" data-bs-toggle="dropdown" href="https://www.spotrac.com/nba" tabindex="-1">
#            NBA
#           </a>
#           <div class="dropdown-menu p-0">
#            <div class="d-flex flex-wrap flex-sm-nowrap px-2">
#             <div class="mega-dropdown-column pt-1 pt-lg-4 pb-4 px-2 px-lg-3">
#              <div class="widget widget-links mb-4">
#               <a class="widget-list-link" href="https://www.spotrac.com/nba">
#                <h6 class="fs-base mb-3">
#                 Home
#                </h6>
#               </a>
#              </div>
#              <div class="widget widget-links mb-4">
#               <a class="widget-list-link" href="https://www.spotrac.com/nba/teams">
#                <h6 class="fs-base mb-3">
#                 Teams
#                </h6>
#               </a>
#              </div>
#              <div class="widget widget-links mb-4">
#               <h6 class="fs-base mb-3">
#                Popular Pages
#               </h6>
#               <ul class="widget-list">
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nba/cap">
#                  Team Cap
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nba/tax">
#                  Team Tax
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nba/rankings">
#                  Rankings
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nba/contracts">
#                  Contracts
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nba/free-agents">
#                  Free Agents
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nba/draft">
#                  Draft
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nba/trade-machine">
#                  Trade Machine
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div class="widget widget-links mb-4">
#               <h6 class="fs-base mb-3">
#                Transactions
#               </h6>
#               <ul class="widget-list">
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nba/transactions">
#                  All Transactions
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nba/transactions/trade">
#                  Trades
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nfl/fines-suspensions">
#                  Fines &amp; Suspensions
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div class="widget widget-links mb-4">
#               <h6 class="fs-base mb-3">
#                Trending Players
#               </h6>
#               <ul class="widget-list">
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/redirect/player/2717">
#                  Kevin Durant
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/redirect/player/10811">
#                  Bradley Beal
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/redirect/player/17841">
#                  Devin Booker
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/redirect/player/70643">
#                  Anthony Edwards
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/redirect/player/2257">
#                  LeBron James
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <div class="mega-dropdown-column-3 pt-1 pt-lg-4 pb-4 px-2 px-lg-3 w-100">
#              <div class="row p-0">
#               <div class="col-md-4 col-sm-6 mb-3">
#                <h6 class="fs-base mb-3">
#                 Southeast
#                </h6>
#                <ul class="widget-list">
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nba/atlanta-hawks/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/nba_atl.png" width="25"/>
# ...
#              <span class="me-2 text-danger fw-bold">
#               5
#              </span>
#              <span class="text-body">
#               Kevin Pillar
#               <small>
#                (CF, CHW)
#               </small>
#              </span>
#             </span>
#             <span class="small">
#              <span class="text-lightblue">
#               <i class="ci-arrow-right">
#               </i>
#              </span>
#             </span>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="ad ad-wrapper text-center">
#         </div>
#         <!--- TRENDING PAGES --->
#         <div class="card mb-3 widget">
#          <div class="card-body p-3">
#           <h2 class="h5 text-info">
#            TRENDING PAGES
#           </h2>
#           <ul class="list-group">
#            <li class="list-group-item d-flex list-group-item-secondary justify-content-between align-items-center cursor p-2" onclick="javascript: document.location='https://www.spotrac.com/mlb/transactions'" style="cursor: pointer;">
#             <span>
#              <span class="me-2 text-danger fw-bold">
#               1
#              </span>
#              <span class="text-body">
#               MLB Transactions
#              </span>
#             </span>
#             <span class="small">
#              <span class="text-lightblue">
#               <i class="ci-arrow-right">
#               </i>
#              </span>
#             </span>
#            </li>
#            <li class="list-group-item d-flex justify-content-between align-items-center cursor p-2" onclick="javascript: document.location='https://www.spotrac.com/mlb/free-agents'" style="cursor: pointer;">
#             <span>
#              <span class="me-2 text-danger fw-bold">
#               2
#              </span>
#              <span class="text-body">
#               MLB Free Agents
#              </span>
#             </span>
#             <span class="small">
#              <span class="text-lightblue">
#               <i class="ci-arrow-right">
#               </i>
#              </span>
#             </span>
#            </li>
#            <li class="list-group-item d-flex list-group-item-secondary justify-content-between align-items-center cursor p-2" onclick="javascript: document.location='https://www.spotrac.com/mlb/payroll'" style="cursor: pointer;">
#             <span>
#              <span class="me-2 text-danger fw-bold">
#               3
#              </span>
#              <span class="text-body">
#               MLB Cap Tracker
#              </span>
#             </span>
#             <span class="small">
#              <span class="text-lightblue">
#               <i class="ci-arrow-right">
#               </i>
#              </span>
#             </span>
#            </li>
#            <li class="list-group-item d-flex justify-content-between align-items-center cursor p-2" onclick="javascript: document.location='https://www.spotrac.com/mlb/rankings'" style="cursor: pointer;">
#             <span>
#              <span class="me-2 text-danger fw-bold">
#               4
#              </span>
#              <span class="text-body">
#               MLB Rankings
#              </span>
#             </span>
#             <span class="small">
#              <span class="text-lightblue">
#               <i class="ci-arrow-right">
#               </i>
#              </span>
#             </span>
#            </li>
#            <li class="list-group-item d-flex list-group-item-secondary justify-content-between align-items-center cursor p-2" onclick="javascript: document.location='https://www.spotrac.com/mlb/rankings/player'" style="cursor: pointer;">
#             <span>
#              <span class="me-2 text-danger fw-bold">
#               5
#              </span>
#              <span class="text-body">
#               MLB Salary Rankings
#              </span>
#             </span>
#             <span class="small">
#              <span class="text-lightblue">
#               <i class="ci-arrow-right">
#               </i>
#              </span>
#             </span>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="ad ad-wrapper text-center">
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#    </div>
#   </main>
#   <!-- footer -->
#   <!-- Footer-->
#   <footer class="footer bg-darker pt-5">
#    <div class="container">
#     <div class="row pb-2">
#      <div class="col-md-2 col-sm-6">
#       <div class="widget widget-links widget-light pb-2 mb-4">
#        <h3 class="widget-title text-light">
#         Leagues &amp; Sports
#        </h3>
#        <ul class="widget-list">
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/nfl">
#           NFL
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/nba">
#           NBA
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/mlb">
#           MLB
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/nhl">
#           NHL
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/wnba">
#           WNBA
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/epl">
#           EPL
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/mls">
#           MLS
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/nwsl">
#           NWSL
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/nascar">
#           NAS
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/formula1">
#           F1
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/atp">
#           ATP
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/wta">
#           WTA
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="col-md-2 col-sm-6">
#       <div class="widget widget-links widget-light pb-2 mb-4">
#        <h3 class="widget-title text-light">
#         Media
#        </h3>
#        <ul class="widget-list">
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://www.spotrac.com/news">
#           News
#          </a>
#         </li>
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://www.spotrac.com/podcasts">
#           Podcasts
#          </a>
#         </li>
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://www.youtube.com/c/TheSpotracPodcast">
#           Videos
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="col-md-2 col-sm-6">
#       <div class="widget widget-links widget-light pb-2 mb-4">
#        <h3 class="widget-title text-light">
#         Contact &amp; Requests
#        </h3>
#        <ul class="widget-list">
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://www.spotrac.com/contact">
#           Contact Us
#          </a>
#         </li>
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://www.spotrac.com/media">
#           Media Requests
#          </a>
#         </li>
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://www.spotrac.com/advertise">
#           Advertise with Us
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="col-md-2 col-sm-6">
#       <div class="widget widget-links widget-light pb-2 mb-4">
#        <h3 class="widget-title text-light">
#         About Spotrac
#        </h3>
#        <ul class="widget-list">
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://www.spotrac.com/about">
#           About Spotrac
#          </a>
#         </li>
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://www.spotrac.com/privacy">
#           Privacy Policy
#          </a>
#         </li>
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://www.spotrac.com/service">
#           Terms of Service
#          </a>
#         </li>
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://policies.google.com/technologies/partner-sites" target="_blank">
#           Google Privacy
#          </a>
#         </li>
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://www.spotrac.com/accessibility">
#           Accessibility
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="col-md-4">
#       <div class="widget pb-2 mb-4">
#        <h3 class="widget-title text-light pb-1">
#         The Spotrac Newsletter
#        </h3>
#        <p class="fs-sm" style="color:rgba(255, 255, 255, 0.65)">
#         Subscribe to our newsletter to receive updates on the latest from Spotrac.
#        </p>
#        <div class="input-group flex-nowrap" onclick="javascript:document.location='https://www.spotrac.com/news/newsletter'">
#         <a class="btn btn-sm btn-primary d-inline-block" href="https://www.spotrac.com/news/newsletter">
#          Click to Subscribe*
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="pt-0 bg-darker">
#     <div class="container">
#      <hr class="hr-light mb-5"/>
#      <div class="row pb-2">
#       <div class="col-md-6 text-center text-md-start mb-1">
#        <div class="text-nowrap mb-1">
#         <a class="d-inline-block align-middle mt-n1 me-3" href="#">
#          <img alt="Spotrac" class="d-block" src="https://www.spotrac.com/public/img/logo-white.png" width="117"/>
#         </a>
#        </div>
#       </div>
#       <div class="col-md-6 text-center text-md-end mb-1">
#        <div class="mb-3">
#         <a class="btn-social bs-light bs-twitter ms-2 mb-2" href="https://twitter.com/spotrac">
#          <i class="ci-twitter">
#          </i>
#         </a>
#         <a class="btn-social bs-light bs-facebook ms-2 mb-2" href="https://www.facebook.com/spotrac/">
#          <i class="ci-facebook">
#          </i>
#         </a>
#         <a class="btn-social bs-light bs-instagram ms-2 mb-2" href="https://www.instagram.com/spotrac/">
#          <i class="ci-instagram">
#          </i>
#         </a>
#         <a class="btn-social bs-light bs-youtube ms-2 mb-2" href="https://www.youtube.com/c/TheSpotracPodcast">
#          <i class="ci-youtube">
#          </i>
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="pb-4 fs-xs text-light opacity-50 text-center text-md-start">
#       Partnered with the USA TODAY Sports Media Group
#       <span class="px-3">
#        |
#       </span>
#       <a class="me-2" href="https://sportsdata.io/">
#        <img src="https://sportsdata.io/assets/images/badges/sportsdataio_light_100.png?v=1" style="line-height: 2.125rem; height:75%; padding-top:5px"/>
#       </a>
#      </div>
#      <div class="pb-4 fs-xs text-light opacity-50 text-center text-md-start">
#       ©
#       <strong>
#        Spotrac
#       </strong>
#       2024. All rights reserved.
#      </div>
#      <div class="pb-4 fs-xs text-light opacity-50 text-center text-md-start">
#       This website is not directly or indirectly affiliated, associated, or connected in any way to Major League Baseball, the National Basketball Association, the National Football League or the National Hockey League. Use of any marks, trademarks, or logos on this website shall not constitute a sponsorship or endorsement by the trademark holder.
#      </div>
#     </div>
#    </div>
#   </footer>
#   <div class="position-fixed top-0 start-50 translate-middle-x p-3" style="z-index: 11">
#    <div aria-atomic="true" aria-live="assertive" class="toast" id="table-copied-toast" role="alert">
#     <div class="toast-header bg-info text-white">
#      <strong class="me-auto">
#       Copied!
#      </strong>
#      <button aria-label="Close" class="btn-close text-white" data-bs-dismiss="toast" type="button">
#      </button>
#     </div>
#     <div class="toast-body">
#      Table has been copied!
#     </div>
#    </div>
#   </div>
#   <!-- Back To Top Button-->
#   <a class="btn-scroll-top" data-scroll="" href="#top">
#    <span class="btn-scroll-top-tooltip text-muted fs-sm me-2">
#     Top
#    </span>
#    <i class="btn-scroll-top-icon ci-arrow-up">
#    </i>
#   </a>
#   <!-- Vendor scrits: js libraries and plugins-->
#   <script src="https://www.spotrac.com/public/vendor/bootstrap/dist/js/bootstrap.bundle.min.js">
#   </script>
#   <script src="https://www.spotrac.com/public/vendor/simplebar/dist/simplebar.min.js">
#   </script>
#   <script src="https://www.spotrac.com/public/vendor/tiny-slider/dist/min/tiny-slider.js">
#   </script>
#   <script src="https://www.spotrac.com/public/vendor/smooth-scroll/dist/smooth-scroll.polyfills.min.js">
#   </script>
#   <script src="https://www.spotrac.com/public/vendor/jquery.doubleScroll/jquery.doubleScroll.js">
#   </script>
#   <script src="https://www.spotrac.com/public/vendor/table2csv/table2csv.min.js">
#   </script>
#   <script src="https://www.spotrac.com/public/vendor/tablesorter/jquery.tablesorter.min.js">
#   </script>
#   <script src="https://www.spotrac.com/public/vendor/clipboard/clipboard.min.js">
#   </script>
#   <script src="https://www.spotrac.com/public/vendor/imagesloaded/imagesloaded.pkgd.min.js">
#   </script>
#   <script src="https://www.spotrac.com/public/vendor/shufflejs/dist/shuffle.min.js">
#   </script>
#   <script src="https://www.spotrac.com/public/vendor/jquery.mousewheel/jquery.mousewheel.min.js">
#   </script>
#   <!-- Main theme script-->
#   <script src="https://www.spotrac.com/public/js/theme.js">
#   </script>
#   <!-- Additional theme script-->
#   <script src="https://www.spotrac.com/public/js/theme-custom.js">
#   </script>
#   <!-- GA4 -->
#   <!-- Page specific script-->
#   <script>
#    // FILTER
#
# $(document).on("change", "form#filter input", function(){
#
#     $("#filtering").removeClass("d-none");
#
#     //
#
#     run_filter()
#
# })
#
# $(document).on("change", "form#filter select", function(){
#
#     $("#filtering").removeClass("d-none");
#
#     //
#
#     run_filter()
#
# })
#
# // SORT
#
# $(document).on("click", "th.cursor", function(){
#
#     $("form#filter input[name='sort']").val( $(this).data('sort') );
#
#     //
#
#     run_filter()
#
# });
#
#
#
# $(document).on("click", "a#year-prev, a#year-next", function(e){
#
#     e.preventDefault();
#
#
#     $("form#filter input[name='year']").val( $(this).data('year') );
#
#     //
#
#     run_filter()
#
# });
#
# function run_filter()
# {
#     //$("#filtering-icon").removeClass("d-none");
#     $(".filtering-overlay").removeClass("d-none");
#
#     //
#
#     var nextURL = $("form#filter").data('action');
#
#     var selections = $("form#filter").serializeArray();
#
#     var params = '';
#     for(var i=0; i<selections.length; i++)
#     {
#         if(selections[i].value!='')
#         {
#             params += "/"+selections[i].name+"/"+selections[i].value;
#         }
#     }
#
#     nextURL = nextURL+'/_'+params;
#
#    $("div#table").addClass("blur")
#
# 	$.ajax({
#         type: 'post',
#         url: nextURL,
# 		data: 'ajax=true',
#         success: function(data){
#             $("#table-wrapper").html(data)
#             //$("#filtering").addClass("d-none");
#             //$("#filtering-icon").addClass("d-none");
#
#         }
#     });
#
# 	// update url history
#     window.history.pushState({href: nextURL}, '', nextURL);
# }
#   </script>
#  </body>
# </html>

# %%
#list of position urls
position_urls = [
    url1,
    url2,
    url3,
    url4,
    url5,
    url6,
    url7,
    url8,
    url9,
    url10
]

def scrape_contract_data(url):
    # Fetch the webpage
    response = requests.get(url)
    data_list = []
    if response.status_code == 200:
        # Parse the HTML
        soup = BeautifulSoup(response.text, 'html.parser')

        # Navigate to the ordered list of players
        ol_path = soup.select_one('body main div section div div div section article > div:nth-of-type(3) > div:nth-of-type(2) > div:nth-of-type(4) > div:nth-of-type(2) ol')
        player_items = ol_path.find_all('li')

        # Extract information for each player in the list
        for item in player_items:
            player_name = item.select_one('div a').text.strip() if item.select_one('div a') else 'N/A'
            contract_length = item.select_one('div:nth-of-type(2)').text.strip() if item.select_one('div:nth-of-type(2)') else 'N/A'
            team_position_info = item.select_one('div div').text.strip() if item.select_one('div div') else 'N/A\nN/A, N/A'
            team_position_info = team_position_info.split('\n')[-1]  # Split and take the part after the newline
            team, position = (team_position_info.split(',', 1) if ',' in team_position_info else ('N/A', 'N/A'))

            data_list.append({
                'PlayerName': player_name,
                'PlayerTeam': team.strip(),
                'PlayerPosition': position.strip(),
                'ContractLength': contract_length
            })

    else:
        print(f"Failed to retrieve data from {url}")
    return data_list

# List to store each player's data
all_players_data = []

# Scrape data from each URL and add it to the list
for url in position_urls:
    players_data = scrape_contract_data(url)
    all_players_data.extend(players_data)

# Create a DataFrame from the list of data
contracts_df = pd.DataFrame(all_players_data)

# Display the DataFrame
print(contracts_df)
# Out:
#              PlayerName PlayerTeam PlayerPosition ContractLength
# 0            Will Smith        LAD              C             10
# 1          Keibert Ruiz        WSH              C              8
# 2           Sean Murphy        ATL              C              6
# 3     Willson Contreras        STL              C              5
# 4         J.T. Realmuto        PHI              C              5
# 5          Bryce Harper        PHI             1B             13
# 6            Matt Olson        ATL             1B              8
# 7      Jake Cronenworth         SD             1B              7
# 8           Kris Bryant        COL             1B              7
# 9       Freddie Freeman        LAD             1B              6
# 10      Xander Bogaerts         SD             2B             11
# 11          Jose Altuve        HOU             2B              7
# 12       Andres Gimenez        CLE             2B              7
# 13        Marcus Semien        TEX             2B              7
# 14         Ozzie Albies        ATL             2B              7
# 15        Rafael Devers        BOS             3B             10
# 16         Austin Riley        ATL             3B             10
# 17       Ke'Bryan Hayes        PIT             3B              8
# 18        Nolan Arenado        STL             3B              8
# 19         José Ramírez        CLE             3B              7
# 20         Mookie Betts        LAD             SS             12
# 21        Wander Franco         TB             SS             11
# 22       Bobby Witt Jr.         KC             SS             11
# 23          Trea Turner        PHI             SS             11
# 24         Corey Seager        TEX             SS             10
# 25   Fernando Tatis Jr.         SD             RF             14
# 26      Jackson Chourio        MIL             RF              8
# 27     Ronald Acuña Jr.        ATL             RF              8
# 28       Bryan Reynolds        PIT             RF              8
# 29       Corbin Carroll        ARI             RF              8
# 30           Mike Trout        LAA             CF             12
# 31      Julio Rodriguez        SEA             CF             12
# 32          Aaron Judge        NYY             CF              9
# 33    Michael Harris II        ATL             CF              8
# 34     Ceddanne Rafaela        BOS             CF              8
# 35        Brandon Nimmo        NYM             LF              8
# 36     Christian Yelich        MIL             LF              7
# 37       Yordan Alvarez        HOU             LF              6
# 38    Andrew Benintendi        CHW             LF              5
# 39  Lourdes Gurriel Jr.        ARI             LF              3
# 40   Yoshinobu Yamamoto        LAD             SP             12
# 41        Shohei Ohtani        LAD             SP             10
# 42          Gerrit Cole        NYY             SP              9
# 43         Jose Berrios        TOR             SP              7
# 44           Aaron Nola        PHI             SP              7
# 45    Giancarlo Stanton        NYY             DH             13
# 46        Manny Machado         SD             DH             11
# 47         Eloy Jimenez        CHW             DH              6
# 48     Nick Castellanos        PHI             DH              5
# 49     Masataka Yoshida        BOS             DH              5

# %%
#urls for contract valuation info
#catchers contracts
url11 = 'https://www.spotrac.com/mlb/rankings/player/_/year/2024/position/c/sort/contract_value'

#1B contracts
url12 = 'https://www.spotrac.com/mlb/rankings/player/_/year/2024/position/1b/sort/contract_value'

#2B contracts
url13 = 'https://www.spotrac.com/mlb/rankings/player/_/year/2024/position/2b/sort/contract_value'

#3B contracts
url14 = 'https://www.spotrac.com/mlb/rankings/player/_/year/2024/position/3b/sort/contract_value'

#SS contracts
url15 = 'https://www.spotrac.com/mlb/rankings/player/_/year/2024/position/ss/sort/contract_value'

#RF contracts
url16 = 'https://www.spotrac.com/mlb/rankings/player/_/year/2024/position/rf/sort/contract_value'

#CF contracts
url17 = 'https://www.spotrac.com/mlb/rankings/player/_/year/2024/position/cf/sort/contract_value'

#LF contracts
url18 = 'https://www.spotrac.com/mlb/rankings/player/_/year/2024/position/lf/sort/contract_value'

#pitchers contracts
url19 = 'https://www.spotrac.com/mlb/rankings/player/_/year/2024/position/p/sort/contract_value'

#DH contracts
url20 = 'https://www.spotrac.com/mlb/rankings/player/_/year/2024/position/dh/sort/contract_value'

# %%
additional_request = requests.get(url11)

# %%
additional_request
# Out:
# <Response [200]>

# %%
additional_request.text
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n  \n\t<head>\n\t<meta charset="utf-8">\n\t<title>2024 MLB Salary Rankings</title>\n\t\n    <!-- SEO Meta Tags-->\n\t<meta name="description" content="Listing the top salaries, cap hits, cash, earnings, contracts, and bonuses, for all active MLB players.">\n\t<meta name="keywords" content="2024, MLB, rankings, player, team, position">\n\t<meta name="author" content="Spotrac">\n\t\n    <!-- Viewport-->\n\t<meta name="viewport" content="width=device-width, initial-scale=1">\n    \n    <meta property="fb:app_id" content="206107179423868" />\n    <meta property="fb:admins" content="513540967"/>\n    <meta property="og:site_name" content="spotrac.com" />\n    <meta property="og:url" content="https://www.spotrac.com/mlb/rankings/player/_/year/2024/position/c/sort/contract_value" />\n    <meta property="og:title" content="2024 MLB Salary Rankings"/>\n        <meta property="og:description" content="Listing the top salaries, cap hits, cash, earnings, contracts, and bonuses, for all active MLB players." />\n        <meta property="og:image" content="https://www.spotrac.com/public/img/logo-tall-white.png"/>\n        <meta property="og:type" content="website" />\n    <meta name="twitter:site" content="spotrac.com" />\n    <meta name="twitter:url" content="https://www.spotrac.com/mlb/rankings/player/_/year/2024/position/c/sort/contract_value" />\n    <meta name="twitter:title" content="2024 MLB Salary Rankings"/>\n        <meta property="twitter:description" content="Listing the top salaries, cap hits, cash, earnings, contracts, and bonuses, for all active MLB players." />\n        <meta name="twitter:image" content="https://www.spotrac.com/public/img/logo-tall-white.png"/>\n    <meta name="twitter:card" content="summary">\n    <meta name="title" content="2024 MLB Salary Rankings"/>    \n    \n    \n    <link rel="canonical" href="https://www.spotrac.com/mlb/rankings/player/_/year/2024/position/c/sort/contract_value" />\t\n    <!-- Favicon and Touch Icons-->\n    <link rel="icon" type="image/x-icon" href="https://www.spotrac.com/public/img/favicon.ico">\n\t<link rel="apple-touch-icon" sizes="180x180" href="https://www.spotrac.com/public/img/favicon.ico">\n\t<link rel="icon" type="image/png" sizes="32x32" href="https://www.spotrac.com/public/img/favicon.ico">\n\t<link rel="icon" type="image/png" sizes="16x16" href="https://www.spotrac.com/public/img/favicon.ico">\n\t<link rel="mask-icon" color="#fe6a6a" href="https://www.spotrac.com/public/img/favicon.ico">\n\t<meta name="msapplication-TileColor" content="#ffffff">\n\t<meta name="theme-color" content="#ffffff">\n\t\n\t<!-- Vendor Styles including: Font Icons, Plugins, etc.-->\n\t<link rel="stylesheet" media="screen" href="https://www.spotrac.com/public/vendor/simplebar/dist/simplebar.min.css"/>\n\t<link rel="stylesheet" media="screen" href="https://www.spotrac.com/public/vendor/tiny-slider/dist/tiny-slider.css"/>\n\t<link href=\'https://www.spotrac.com/public/fonts/roboto.css\' rel=\'stylesheet\' type=\'text/css\'>\n\t\t\n\t<!-- Main Theme Styles + Bootstrap-->\n\t<link rel="stylesheet" media="screen" href="https://www.spotrac.com/public/css/theme.css">\n\t<link rel="stylesheet" media="screen" href="https://www.spotrac.com/public/css/custom-theme.css">\n\t<link rel="stylesheet" media="screen" href="https://www.spotrac.com/public/css/custom-theme-big.css">\n\t<link rel="stylesheet" media="screen" href="https://www.spotrac.com/public/css/custom-nav.css">\n\t<link rel="stylesheet" media="screen" href="https://www.spotrac.com/public/css/custom-table.css">\n\t<link rel="stylesheet" media="screen" href="https://www.spotrac.com/public/css/custom-filter.css">\n\t<link rel="stylesheet" media="screen" href="https://www.spotrac.com/public/css/custom-colors.css">\n\n\n    <script src="https://www.spotrac.com/public/vendor/jquery/jquery-3.6.1.min.js"></script>\n\n    <!-- jQuery-->\n        <script src="https://www.spotrac.com/public/vendor/kit-73b9c60b16-web/js/all.m ...

# %%
values_html = BeautifulSoup(additional_request.text, 'html.parser')
print(values_html.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    2024 MLB Salary Rankings
#   </title>
#   <!-- SEO Meta Tags-->
#   <meta content="Listing the top salaries, cap hits, cash, earnings, contracts, and bonuses, for all active MLB players." name="description"/>
#   <meta content="2024, MLB, rankings, player, team, position" name="keywords"/>
#   <meta content="Spotrac" name="author"/>
#   <!-- Viewport-->
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="206107179423868" property="fb:app_id">
#    <meta content="513540967" property="fb:admins">
#     <meta content="spotrac.com" property="og:site_name">
#      <meta content="https://www.spotrac.com/mlb/rankings/player/_/year/2024/position/c/sort/contract_value" property="og:url">
#       <meta content="2024 MLB Salary Rankings" property="og:title">
#        <meta content="Listing the top salaries, cap hits, cash, earnings, contracts, and bonuses, for all active MLB players." property="og:description"/>
#        <meta content="https://www.spotrac.com/public/img/logo-tall-white.png" property="og:image"/>
#        <meta content="website" property="og:type"/>
#        <meta content="spotrac.com" name="twitter:site"/>
#        <meta content="https://www.spotrac.com/mlb/rankings/player/_/year/2024/position/c/sort/contract_value" name="twitter:url"/>
#        <meta content="2024 MLB Salary Rankings" name="twitter:title"/>
#        <meta content="Listing the top salaries, cap hits, cash, earnings, contracts, and bonuses, for all active MLB players." property="twitter:description"/>
#        <meta content="https://www.spotrac.com/public/img/logo-tall-white.png" name="twitter:image"/>
#        <meta content="summary" name="twitter:card"/>
#        <meta content="2024 MLB Salary Rankings" name="title">
#         <link href="https://www.spotrac.com/mlb/rankings/player/_/year/2024/position/c/sort/contract_value" rel="canonical"/>
#         <!-- Favicon and Touch Icons-->
#         <link href="https://www.spotrac.com/public/img/favicon.ico" rel="icon" type="image/x-icon"/>
#         <link href="https://www.spotrac.com/public/img/favicon.ico" rel="apple-touch-icon" sizes="180x180"/>
#         <link href="https://www.spotrac.com/public/img/favicon.ico" rel="icon" sizes="32x32" type="image/png"/>
#         <link href="https://www.spotrac.com/public/img/favicon.ico" rel="icon" sizes="16x16" type="image/png"/>
#         <link color="#fe6a6a" href="https://www.spotrac.com/public/img/favicon.ico" rel="mask-icon"/>
#         <meta content="#ffffff" name="msapplication-TileColor"/>
#         <meta content="#ffffff" name="theme-color"/>
#         <!-- Vendor Styles including: Font Icons, Plugins, etc.-->
#         <link href="https://www.spotrac.com/public/vendor/simplebar/dist/simplebar.min.css" media="screen" rel="stylesheet">
#          <link href="https://www.spotrac.com/public/vendor/tiny-slider/dist/tiny-slider.css" media="screen" rel="stylesheet">
#           <link href="https://www.spotrac.com/public/fonts/roboto.css" rel="stylesheet" type="text/css"/>
#           <!-- Main Theme Styles + Bootstrap-->
#           <link href="https://www.spotrac.com/public/css/theme.css" media="screen" rel="stylesheet"/>
#           <link href="https://www.spotrac.com/public/css/custom-theme.css" media="screen" rel="stylesheet"/>
#           <link href="https://www.spotrac.com/public/css/custom-theme-big.css" media="screen" rel="stylesheet"/>
#           <link href="https://www.spotrac.com/public/css/custom-nav.css" media="screen" rel="stylesheet"/>
#           <link href="https://www.spotrac.com/public/css/custom-table.css" media="screen" rel="stylesheet"/>
#           <link href="https://www.spotrac.com/public/css/custom-filter.css" media="screen" rel="stylesheet"/>
#           <link href="https://www.spotrac.com/public/css/custom-colors.css" media="screen" rel="stylesheet"/>
#           <script src="https://www.spotrac.com/public/vendor/jquery/jquery-3.6.1.min.js">
#           </script>
#           <!-- jQuery-->
#           <script crossorigin="anonymous" src="https://www.spotrac.com/public/vendor/kit-73b9c60b16-web/js/all.min.js">
#           </script>
#           <!-- Google Recaptcha -->
#           <script src="https://www.google.com/recaptcha/api.js">
#           </script>
#           <!-- Google Analytics: GA4 -->
#           <!-- Global site tag (gtag.js) - Google Analytics -->
#           <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-3ZZTGEXZ3B">
#           </script>
#           <script>
#            window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-3ZZTGEXZ3B');
#           </script>
#           <!-- BEGIN THM AUTO CODE -->
#           <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#           </script>
#           <script type="text/javascript">
#            var googletag = googletag || {};
#     googletag.cmd = googletag.cmd || [];
#     googletag.cmd.push(function() {
#       googletag.pubads().disableInitialLoad(); googletag.pubads().enableSingleRequest();
#     });
#     var _hbopts = { alias: '/', type: 'banner' };
#     var _hbwrap = _hbwrap || [];
#     (function() {
#       var hbldr = function (url, resolution, cachebuster, millis, referrer) {
#         var s = document.createElement('script'); s.type = 'text/javascript';
#         s.async = true; s.src = 'https://' + url + '&resolution=' + resolution +
#           '&random=' + cachebuster + '&millis=' + millis + '&referrer=' + referrer;
#         var x = document.getElementsByTagName('script')[0];
#         x.parentNode.insertBefore(s, x);
#       };
#       hbldr(
#         'tradecore.tradehouse.media/servlet/hbwrap?stack=11',
#         (window.innerWidth||screen.width)+'x'+(window.innerHeight||screen.height),
#         Math.floor(89999999*Math.random()+10000000), new Date().getTime(), encodeURIComponent(
#           (window!=top&&window.location.ancestorOrigins)?
#             window.location.ancestorOrigins[window.location.ancestorOrigins.length-1]:document.location
#         )
#       );
#     })();
#           </script>
#           <!-- END THM AUTO CODE -->
#           <!-- Mailchimp-->
#           <!-- Page specific css-->
#           <style>
#            .stat-wrapper h2 {
#     font: 800 15px/16px 'Roboto', sans-serif !important;
#     color: #006699;
#     padding-bottom: 5px;
#     margin: 0px;
#     margin-bottom: 10px;
#     text-transform: uppercase;
#     border-bottom: 1px solid #ccc;
# }
#
# .stat-wrapper{ padding:10px; min-height:200px;}
# .stat-wrapper ol { margin:0px;padding:0px 15px;}
# .stat-wrapper ol li::before {
#     color: red !important;
#     font-weight: bold !important;
# }
# .stat-wrapper li { clear:both; width: 100%; font-size: 14px; font-weight: bold; margin-left: 0; padding: 3px 0px; line-height: 16px; }
#
# .stat-wrapper li .name{ float: left; width: 60%; padding-left:3px; font-size: 12px; font-weight: normal; }
# .stat-wrapper li .team-position{ font-size: 10px; font-weight: normal; color:#ADADAD; display: inline; margin-left: 8px; }
# .stat-wrapper li .name a{  color: #cc3333; }
# .stat-wrapper li .value{ float: right; width: 40%; text-align: right; font-size: 12px; font-weight: normal;}
# .stat-wrapper .more{ color: #006699; float:right }
#
# .stat-wrapper2 li .name{ float: left; width: 60%; padding-left:8px; font-size: 12px; font-weight: normal; }
#
#
# @media (max-width: 767px) {
#
#
# }
#           </style>
#          </link>
#         </link>
#        </meta>
#       </meta>
#      </meta>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <!-- body -->
#  <body class="handheld-toolbar-enabled">
#   <!-- main -->
#   <main class="page-wrapper">
#    <!-- Sign in / sign up modal-->
#    <div class="modal fade" id="signin-modal" role="dialog" tabindex="-1">
#     <div class="modal-dialog" role="document">
#      <div class="modal-content">
#       <div class="modal-header bg-secondary">
#        <ul class="nav nav-tabs card-header-tabs" role="tablist">
#         <li class="nav-item">
#          <a aria-selected="true" class="nav-link fw-medium active" data-bs-toggle="tab" href="#signin-tab" role="tab">
#           <i class="ci-unlocked me-2 mt-n1">
#           </i>
#           Sign in
#          </a>
#         </li>
#         <li class="nav-item">
#          <a aria-selected="false" class="nav-link fw-medium" data-bs-toggle="tab" href="#signup-tab" role="tab">
#           <i class="ci-user me-2 mt-n1">
#           </i>
#           Sign up
#          </a>
#         </li>
#        </ul>
#        <button aria-label="Close" class="btn-close" data-bs-dismiss="modal" type="button">
#        </button>
#       </div>
#       <div class="modal-body tab-content py-4">
#        <form action="https://www.spotrac.com/login/submit" autocomplete="off" class="needs-validation tab-pane fade show active" id="signin-tab" method="post" novalidate="">
#         <input id="goto1" name="goto" type="hidden" value="https://www.spotrac.com/mlb/rankings/player/_/year/2024/position/c/sort/contract_value"/>
#         <div class="mb-3">
#          <label class="form-label" for="si-email">
#           Email address
#          </label>
#          <input class="form-control form-control-sm" id="si-email" name="email" placeholder="johndoe@example.com" required="" type="email"/>
#          <div class="invalid-feedback">
#           Please provide a valid email address.
#          </div>
#         </div>
#         <div class="mb-3">
#          <label class="form-label" for="si-password">
#           Password
#          </label>
#          <div class="password-toggle">
#           <input class="form-control form-control-sm" id="si-password" name="password" required="" type="password"/>
#           <label aria-label="Show/hide password" class="password-toggle-btn">
#            <input class="password-toggle-check" type="checkbox"/>
#            <span class="password-toggle-indicator">
#            </span>
#           </label>
#          </div>
#         </div>
#         <div class="mb-3 d-flex flex-wrap justify-content-between">
#          <div class="form-check mb-2">
#          </div>
#          <a class="fs-sm" href="https://www.spotrac.com/login/forgot">
#           Forgot password?
#          </a>
#         </div>
#         <button class="btn btn-navy btn-shadow d-block w-100" type="submit">
#          Sign in
#         </button>
#        </form>
#        <form action="https://www.spotrac.com/register/submit" autocomplete="off" class="needs-validation tab-pane fade" id="signup-tab" method="post" novalidate="">
#         <input id="goto2" name="goto" type="hidden" value="https://www.spotrac.com/mlb/rankings/player/_/year/2024/position/c/sort/contract_value">
#          <div class="mb-3 fw-bold">
#           Why sign up for Spotrac Premium?!
#           <ul class="ms-0 ps-3 fw-normal">
#            <li class="float-start w-50">
#             Ad-FREE Experience
#            </li>
#            <li class="float-start w-50">
#             Historical Contract Information
#            </li>
#            <li class="float-start w-50">
#             Historical Team Financials
#            </li>
#            <li class="float-start w-50">
#             Advanced Data Portal
#            </li>
#           </ul>
#          </div>
#          <br/>
#          <div class="mt-3 mb-2 mb-3 fw-bold text-navy">
#           Just $30 per year (recurring)!
#          </div>
#          <div class="mb-3">
#           <label class="form-label" for="su-first-name">
#            First Name
#           </label>
#           <input class="form-control form-control-sm" id="su-first-name" name="first_name" placeholder="John" required="" type="text"/>
#           <div class="invalid-feedback">
#            Please fill in your first name.
#           </div>
#          </div>
#          <div class="mb-3">
#           <label class="form-label" for="su-last-name">
#            Last Name
#           </label>
#           <input class="form-control form-control-sm" id="su-last-name" name="last_name" placeholder=" Doe" required="" type="text"/>
#           <div class="invalid-feedback">
#            Please fill in your last name.
#           </div>
#          </div>
#          <div class="mb-3">
#           <label for="su-email">
#            Email address
#           </label>
#           <input class="form-control form-control-sm" id="su-email" name="email" placeholder="johndoe@example.com" required="" type="email"/>
#           <div class="invalid-feedback">
#            Please provide a valid email address.
#           </div>
#          </div>
#          <div class="mb-3">
#           <label class="form-label" for="su-password">
#            Password
#           </label>
#           <div class="password-toggle">
#            <input class="form-control form-control-sm" id="su-password" name="password" required="" type="password"/>
#            <label aria-label="Show/hide password" class="password-toggle-btn">
#             <input class="password-toggle-check" type="checkbox"/>
#             <span class="password-toggle-indicator">
#             </span>
#            </label>
#           </div>
#          </div>
#          <div class="mb-3">
#           <div class="g-recaptcha" data-sitekey="6LehNE4UAAAAAFK4dftCLAbKcJqwS9tCOlvr94o6">
#           </div>
#          </div>
#          <button class="btn btn-navy btn-shadow d-block w-100" name="submit" type="submit">
#           Sign up
#          </button>
#         </input>
#        </form>
#       </div>
#      </div>
#     </div>
#    </div>
#    <header class="navbar-sticky shadow-sm" id="nav-header">
#     <!-- Remove "navbar-sticky" class to make navigation bar scrollable with the page.-->
#     <div class="bg-light">
#      <div class="navbar navbar-expand-lg navbar-light p-0">
#       <div class="container">
#        <a class="navbar-brand d-none d-sm-block flex-shrink-0" href="https://www.spotrac.com" tabindex="-1">
#         <img alt="spotrac" src="https://www.spotrac.com/public/img/logo.png" width="225"/>
#        </a>
#        <a class="navbar-brand d-sm-none flex-shrink-0 me-2" href="https://www.spotrac.com" tabindex="-1">
#         <img alt="spotrac" src="https://www.spotrac.com/public/img/logo.png" width="100"/>
#        </a>
#        <form action="https://www.spotrac.com/search" method="get" style="display:contents;">
#         <div class="input-group d-none d-lg-flex mx-4">
#          <input class="form-control rounded-end pe-5" name="q" placeholder="Search for a Player" tabindex="-1" type="text"/>
#          <i class="ci-search position-absolute top-50 end-0 translate-middle-y text-muted fs-base me-3">
#          </i>
#         </div>
#        </form>
#        <div class="navbar-toolbar d-flex flex-shrink-0 align-items-center">
#         <button class="navbar-toggler" data-bs-target="#navbarCollapse" data-bs-toggle="collapse" type="button">
#          <span class="navbar-toggler-icon">
#          </span>
#         </button>
#         <a class="navbar-tool navbar-stuck-toggler" href="#">
#          <span class="navbar-tool-tooltip">
#           Expand menu
#          </span>
#         </a>
#         <a class="navbar-tool ms-1 ms-lg-2 me-n1 me-lg-3 text-body d-none d-lg-block" data-bs-toggle="" href="https://twitter.com/spotrac" tabindex="-1" target="_blank">
#          <i class="navbar-tool-icon fa-brands fa-x-twitter">
#          </i>
#         </a>
#         <a class="navbar-tool ms-1 ms-lg-2 me-n1 me-lg-3 text-body d-none d-lg-block" data-bs-toggle="" href="https://www.youtube.com/c/TheSpotracPodcast" tabindex="-1" target="_blank">
#          <i class="navbar-tool-icon fa-brands fa-youtube">
#          </i>
#         </a>
#         <a class="navbar-tool ms-1 ms-lg-2 me-n1 me-lg-3 text-body d-none d-lg-block" data-bs-toggle="" href="https://www.facebook.com/spotrac/" tabindex="-1" target="_blank">
#          <i class="navbar-tool-icon fa-brands fa-facebook-f">
#          </i>
#         </a>
#         <a class="navbar-tool ms-1 ms-lg-2 me-n1 me-lg-3 text-body d-none d-lg-block" data-bs-toggle="" href="https://www.instagram.com/spotrac/" tabindex="-1" target="_blank">
#          <i class="navbar-tool-icon fa-brands fa-instagram">
#          </i>
#         </a>
#         <a class="navbar-tool ms-1 ms-lg-0 me-n1 me-lg-0 d-none d-md-inline-flex" data-bs-toggle="modal" href="#signin-modal" tabindex="-1">
#          <div class="navbar-tool-icon-box">
#           <i class="navbar-tool-icon ci-user">
#           </i>
#          </div>
#         </a>
#         <a class="navbar-tool ms-1 ms-lg-0 me-n1 me-lg-0 d-none d-md-inline-flex" data-bs-toggle="modal" href="#signin-modal" tabindex="-1">
#          <div class="navbar-tool-text ms-n3">
#           <small>
#            Hello, Sign in
#           </small>
#           Premium
#          </div>
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="navbar navbar-expand-lg navbar-mobile navbar-level1 navbar-light mt-0 pt-0 pb-0" style="border-top:1px solid #dae1e7">
#       <div class="container">
#        <div class="collapse navbar-collapse" id="navbarCollapse">
#         <!-- Search-->
#         <form action="https://www.spotrac.com/search" method="get" style="display:contents;">
#          <div class="input-group d-lg-none my-3">
#           <i class="ci-search position-absolute top-50 start-0 translate-middle-y text-muted fs-base ms-3">
#           </i>
#           <input class="form-control rounded-start" name="q" placeholder="Search a Player or Team" tabindex="-1" type="text"/>
#          </div>
#         </form>
#         <ul class="navbar-nav navbar-mega-nav">
#          <li class="nav-item dropdown d-block d-sm-none">
#           <a class="nav-link dropdown-toggle py-0" data-bs-toggle="dropdown" href="#" tabindex="-1">
#            PREMIUM
#           </a>
#           <div class="dropdown-menu p-0">
#            <div class="d-flex flex-wrap flex-sm-nowrap px-2">
#             <div class="mega-dropdown-column pt-1 pt-lg-4 pb-0 px-2 px-lg-3">
#              <div class="widget widget-links mb-4">
#               <ul class="widget-list">
#                <li class="widget-list-item">
#                 <a class="widget-list-link" data-bs-toggle="modal" href="#signin-modal">
#                  My Account
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/logout">
#                  Logout
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li class="nav-item">
#           <a class="nav-link py-0" data-bs-toggle="" href="https://www.spotrac.com/" tabindex="-1">
#            HOME
#           </a>
#          </li>
#          <li class="nav-item dropdown">
#           <a class="nav-link dropdown-toggle py-0" data-bs-toggle="dropdown" href="https://www.spotrac.com/nfl" tabindex="-1">
#            NFL
#           </a>
#           <div class="dropdown-menu p-0">
#            <div class="d-flex flex-wrap flex-sm-nowrap px-2">
#             <div class="mega-dropdown-column pt-1 pt-lg-4 pb-4 px-2 px-lg-3">
#              <div class="widget widget-links mb-4">
#               <a class="widget-list-link" href="https://www.spotrac.com/nfl">
#                <h6 class="fs-base mb-3">
#                 Home
#                </h6>
#               </a>
#              </div>
#              <div class="widget widget-links mb-4">
#               <a class="widget-list-link" href="https://www.spotrac.com/nfl/teams">
#                <h6 class="fs-base mb-3">
#                 Teams
#                </h6>
#               </a>
#              </div>
#              <div class="widget widget-links mb-4">
#               <h6 class="fs-base mb-3">
#                Popular Pages
#               </h6>
#               <ul class="widget-list">
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nfl/cap">
#                  Team Cap
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nfl/rankings">
#                  Rankings
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nfl/contracts">
#                  Contracts
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nfl/free-agents">
#                  Free Agents
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nfl/draft">
#                  Draft
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div class="widget widget-links mb-4">
#               <h6 class="fs-base mb-3">
#                Transactions
#               </h6>
#               <ul class="widget-list">
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nfl/transactions">
#                  All Transactions
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nfl/transactions/trade">
#                  Trades
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nfl/transactions/_/type/signed-extended">
#                  Extensions
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nfl/fines-suspensions">
#                  Fines &amp; Suspensions
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div class="widget widget-links mb-4">
#               <h6 class="fs-base mb-3">
#                Trending Players
#               </h6>
#               <ul class="widget-list">
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/redirect/player/12344">
#                  Travis Kelce
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/redirect/player/18952">
#                  Ezekiel Elliott
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/redirect/player/9915">
#                  Kirk Cousins
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/redirect/player/21751">
#                  Patrick Mahomes
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/redirect/player/72407">
#                  Rashod Bateman
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <div class="mega-dropdown-column-4 pt-1 pt-lg-4 pb-4 px-2 px-lg-3 w-100">
#              <div class="row p-0">
#               <div class="col-md-3 col-sm-6 mb-3">
#                <h6 class="fs-base mb-3">
#                 AFC East
#                </h6>
#                <ul class="widget-list">
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/buffalo-bills/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/buf.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    BUF Bills
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Buffalo Bills
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/miami-dolphins/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/mia.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    MIA Dolphins
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Miami Dolphins
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/new-england-patriots/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/ne.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    NE Patriots
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    New England Patriots
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/new-york-jets/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/nyj.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    NYJ Jets
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    New York Jets
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#               <div class="col-md-3 col-sm-6 mb-3">
#                <h6 class="fs-base mb-3">
#                 AFC North
#                </h6>
#                <ul class="widget-list">
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/baltimore-ravens/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/bal.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    BAL Ravens
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Baltimore Ravens
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/cincinnati-bengals/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/cin.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    CIN Bengals
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Cincinnati Bengals
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/cleveland-browns/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/cle1.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    CLE Browns
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Cleveland Browns
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/pittsburgh-steelers/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/pit.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    PIT Steelers
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Pittsburgh Steelers
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#               <div class="col-md-3 col-sm-6 mb-3">
#                <h6 class="fs-base mb-3">
#                 AFC South
#                </h6>
#                <ul class="widget-list">
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/houston-texans/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/hou.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    HOU Texans
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Houston Texans
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/indianapolis-colts/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/ind1.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    IND Colts
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Indianapolis Colts
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/jacksonville-jaguars/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/jax.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    JAC Jaguars
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Jacksonville Jaguars
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/tennessee-titans/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/ten.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    TEN Titans
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Tennessee Titans
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#               <div class="col-md-3 col-sm-6 mb-3">
#                <h6 class="fs-base mb-3">
#                 AFC West
#                </h6>
#                <ul class="widget-list">
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/denver-broncos/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/den3.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    DEN Broncos
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Denver Broncos
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/kansas-city-chiefs/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/kc1.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    KC Chiefs
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Kansas City Chiefs
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/las-vegas-raiders/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/lv.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    LV Raiders
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Las Vegas Raiders
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/los-angeles-chargers/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/lac.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    LAC Chargers
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Los Angeles Chargers
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#              <div class="row mt-5">
#               <div class="col-md-3 col-sm-6 mb-3">
#                <h6 class="fs-base mb-3">
#                 NFC East
#                </h6>
#                <ul class="widget-list">
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/dallas-cowboys/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/dal.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    DAL Cowboys
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Dallas Cowboys
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/new-york-giants/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/nyg.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    NYG Giants
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    New York Giants
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/philadelphia-eagles/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/phi.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    PHI Eagles
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Philadelphia Eagles
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/washington-commanders/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/was_2022.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    WAS Commanders
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Washington Commanders
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#               <div class="col-md-3 col-sm-6 mb-3">
#                <h6 class="fs-base mb-3">
#                 NFC North
#                </h6>
#                <ul class="widget-list">
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/chicago-bears/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/chi.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    CHI Bears
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Chicago Bears
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/detroit-lions/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/det.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    DET Lions
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Detroit Lions
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/green-bay-packers/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/gb.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    GB Packers
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Green Bay Packers
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/minnesota-vikings/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/min.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    MIN Vikings
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Minnesota Vikings
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#               <div class="col-md-3 col-sm-6 mb-3">
#                <h6 class="fs-base mb-3">
#                 NFC South
#                </h6>
#                <ul class="widget-list">
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/atlanta-falcons/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/atl2.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    ATL Falcons
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Atlanta Falcons
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/carolina-panthers/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/car.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    CAR Panthers
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Carolina Panthers
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/new-orleans-saints/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/no.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    NO Saints
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    New Orleans Saints
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/tampa-bay-buccaneers/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/tb.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    TB Buccaneers
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Tampa Bay Buccaneers
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#               <div class="col-md-3 col-sm-6 mb-3">
#                <h6 class="fs-base mb-3">
#                 NFC West
#                </h6>
#                <ul class="widget-list">
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/arizona-cardinals/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/ari.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    ARI Cardinals
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Arizona Cardinals
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/los-angeles-rams/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/lar.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    LAR Rams
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Los Angeles Rams
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/san-francisco-49ers/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/sf.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    SF 49ers
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    San Francisco 49ers
#                   </span>
#                  </a>
#                 </li>
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nfl/seattle-seahawks/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/sea1.png" width="25"/>
#                   <span class="d-inline-block d-sm-none">
#                    SEA Seahawks
#                   </span>
#                   <span class="d-none d-sm-inline-block">
#                    Seattle Seahawks
#                   </span>
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#          </li>
#          <li class="nav-item dropdown">
#           <a class="nav-link dropdown-toggle py-0" data-bs-toggle="dropdown" href="https://www.spotrac.com/nba" tabindex="-1">
#            NBA
#           </a>
#           <div class="dropdown-menu p-0">
#            <div class="d-flex flex-wrap flex-sm-nowrap px-2">
#             <div class="mega-dropdown-column pt-1 pt-lg-4 pb-4 px-2 px-lg-3">
#              <div class="widget widget-links mb-4">
#               <a class="widget-list-link" href="https://www.spotrac.com/nba">
#                <h6 class="fs-base mb-3">
#                 Home
#                </h6>
#               </a>
#              </div>
#              <div class="widget widget-links mb-4">
#               <a class="widget-list-link" href="https://www.spotrac.com/nba/teams">
#                <h6 class="fs-base mb-3">
#                 Teams
#                </h6>
#               </a>
#              </div>
#              <div class="widget widget-links mb-4">
#               <h6 class="fs-base mb-3">
#                Popular Pages
#               </h6>
#               <ul class="widget-list">
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nba/cap">
#                  Team Cap
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nba/tax">
#                  Team Tax
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nba/rankings">
#                  Rankings
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nba/contracts">
#                  Contracts
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nba/free-agents">
#                  Free Agents
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nba/draft">
#                  Draft
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nba/trade-machine">
#                  Trade Machine
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div class="widget widget-links mb-4">
#               <h6 class="fs-base mb-3">
#                Transactions
#               </h6>
#               <ul class="widget-list">
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nba/transactions">
#                  All Transactions
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nba/transactions/trade">
#                  Trades
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/nfl/fines-suspensions">
#                  Fines &amp; Suspensions
#                 </a>
#                </li>
#               </ul>
#              </div>
#              <div class="widget widget-links mb-4">
#               <h6 class="fs-base mb-3">
#                Trending Players
#               </h6>
#               <ul class="widget-list">
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/redirect/player/2717">
#                  Kevin Durant
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/redirect/player/10811">
#                  Bradley Beal
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/redirect/player/17841">
#                  Devin Booker
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/redirect/player/70643">
#                  Anthony Edwards
#                 </a>
#                </li>
#                <li class="widget-list-item">
#                 <a class="widget-list-link" href="https://www.spotrac.com/redirect/player/2257">
#                  LeBron James
#                 </a>
#                </li>
#               </ul>
#              </div>
#             </div>
#             <div class="mega-dropdown-column-3 pt-1 pt-lg-4 pb-4 px-2 px-lg-3 w-100">
#              <div class="row p-0">
#               <div class="col-md-4 col-sm-6 mb-3">
#                <h6 class="fs-base mb-3">
#                 Southeast
#                </h6>
#                <ul class="widget-list">
#                 <li class="widget-list-item">
#                  <a class="widget-list-link" href="https://www.spotrac.com/nba/atlanta-hawks/overview">
#                   <img class="d-inline-block" src="https://d1dglpr230r57l.cloudfront.net/images/thumb/nba_atl.png" width="25"/>
# ...
#             <span>
#              <span class="me-2 text-danger fw-bold">
#               3
#              </span>
#              <span class="text-body">
#               NFL Transactions
#              </span>
#             </span>
#             <span class="small">
#              <span class="text-lightblue">
#               <i class="ci-arrow-right">
#               </i>
#              </span>
#             </span>
#            </li>
#            <li class="list-group-item d-flex justify-content-between align-items-center cursor p-2" onclick="javascript: document.location='https://www.spotrac.com/epl/leicester-city/payroll'" style="cursor: pointer;">
#             <span>
#              <span class="me-2 text-danger fw-bold">
#               4
#              </span>
#              <span class="text-body">
#               Leicester City Cap
#              </span>
#             </span>
#             <span class="small">
#              <span class="text-lightblue">
#               <i class="ci-arrow-right">
#               </i>
#              </span>
#             </span>
#            </li>
#            <li class="list-group-item d-flex list-group-item-secondary justify-content-between align-items-center cursor p-2" onclick="javascript: document.location='https://www.spotrac.com/nfl/contracts'" style="cursor: pointer;">
#             <span>
#              <span class="me-2 text-danger fw-bold">
#               5
#              </span>
#              <span class="text-body">
#               NFL Contracts
#              </span>
#             </span>
#             <span class="small">
#              <span class="text-lightblue">
#               <i class="ci-arrow-right">
#               </i>
#              </span>
#             </span>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="ad ad-wrapper text-center">
#         </div>
#        </div>
#       </div>
#      </div>
#     </section>
#    </div>
#   </main>
#   <!-- footer -->
#   <!-- Footer-->
#   <footer class="footer bg-darker pt-5">
#    <div class="container">
#     <div class="row pb-2">
#      <div class="col-md-2 col-sm-6">
#       <div class="widget widget-links widget-light pb-2 mb-4">
#        <h3 class="widget-title text-light">
#         Leagues &amp; Sports
#        </h3>
#        <ul class="widget-list">
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/nfl">
#           NFL
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/nba">
#           NBA
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/mlb">
#           MLB
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/nhl">
#           NHL
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/wnba">
#           WNBA
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/epl">
#           EPL
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/mls">
#           MLS
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/nwsl">
#           NWSL
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/nascar">
#           NAS
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/formula1">
#           F1
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/atp">
#           ATP
#          </a>
#         </li>
#         <li class="widget-list-item float-start w-50">
#          <a class="widget-list-link" href="https://www.spotrac.com/wta">
#           WTA
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="col-md-2 col-sm-6">
#       <div class="widget widget-links widget-light pb-2 mb-4">
#        <h3 class="widget-title text-light">
#         Media
#        </h3>
#        <ul class="widget-list">
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://www.spotrac.com/news">
#           News
#          </a>
#         </li>
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://www.spotrac.com/podcasts">
#           Podcasts
#          </a>
#         </li>
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://www.youtube.com/c/TheSpotracPodcast">
#           Videos
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="col-md-2 col-sm-6">
#       <div class="widget widget-links widget-light pb-2 mb-4">
#        <h3 class="widget-title text-light">
#         Contact &amp; Requests
#        </h3>
#        <ul class="widget-list">
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://www.spotrac.com/contact">
#           Contact Us
#          </a>
#         </li>
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://www.spotrac.com/media">
#           Media Requests
#          </a>
#         </li>
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://www.spotrac.com/advertise">
#           Advertise with Us
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="col-md-2 col-sm-6">
#       <div class="widget widget-links widget-light pb-2 mb-4">
#        <h3 class="widget-title text-light">
#         About Spotrac
#        </h3>
#        <ul class="widget-list">
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://www.spotrac.com/about">
#           About Spotrac
#          </a>
#         </li>
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://www.spotrac.com/privacy">
#           Privacy Policy
#          </a>
#         </li>
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://www.spotrac.com/service">
#           Terms of Service
#          </a>
#         </li>
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://policies.google.com/technologies/partner-sites" target="_blank">
#           Google Privacy
#          </a>
#         </li>
#         <li class="widget-list-item">
#          <a class="widget-list-link" href="https://www.spotrac.com/accessibility">
#           Accessibility
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="col-md-4">
#       <div class="widget pb-2 mb-4">
#        <h3 class="widget-title text-light pb-1">
#         The Spotrac Newsletter
#        </h3>
#        <p class="fs-sm" style="color:rgba(255, 255, 255, 0.65)">
#         Subscribe to our newsletter to receive updates on the latest from Spotrac.
#        </p>
#        <div class="input-group flex-nowrap" onclick="javascript:document.location='https://www.spotrac.com/news/newsletter'">
#         <a class="btn btn-sm btn-primary d-inline-block" href="https://www.spotrac.com/news/newsletter">
#          Click to Subscribe*
#         </a>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="pt-0 bg-darker">
#     <div class="container">
#      <hr class="hr-light mb-5"/>
#      <div class="row pb-2">
#       <div class="col-md-6 text-center text-md-start mb-1">
#        <div class="text-nowrap mb-1">
#         <a class="d-inline-block align-middle mt-n1 me-3" href="#">
#          <img alt="Spotrac" class="d-block" src="https://www.spotrac.com/public/img/logo-white.png" width="117"/>
#         </a>
#        </div>
#       </div>
#       <div class="col-md-6 text-center text-md-end mb-1">
#        <div class="mb-3">
#         <a class="btn-social bs-light bs-twitter ms-2 mb-2" href="https://twitter.com/spotrac">
#          <i class="ci-twitter">
#          </i>
#         </a>
#         <a class="btn-social bs-light bs-facebook ms-2 mb-2" href="https://www.facebook.com/spotrac/">
#          <i class="ci-facebook">
#          </i>
#         </a>
#         <a class="btn-social bs-light bs-instagram ms-2 mb-2" href="https://www.instagram.com/spotrac/">
#          <i class="ci-instagram">
#          </i>
#         </a>
#         <a class="btn-social bs-light bs-youtube ms-2 mb-2" href="https://www.youtube.com/c/TheSpotracPodcast">
#          <i class="ci-youtube">
#          </i>
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="pb-4 fs-xs text-light opacity-50 text-center text-md-start">
#       Partnered with the USA TODAY Sports Media Group
#       <span class="px-3">
#        |
#       </span>
#       <a class="me-2" href="https://sportsdata.io/">
#        <img src="https://sportsdata.io/assets/images/badges/sportsdataio_light_100.png?v=1" style="line-height: 2.125rem; height:75%; padding-top:5px"/>
#       </a>
#      </div>
#      <div class="pb-4 fs-xs text-light opacity-50 text-center text-md-start">
#       ©
#       <strong>
#        Spotrac
#       </strong>
#       2024. All rights reserved.
#      </div>
#      <div class="pb-4 fs-xs text-light opacity-50 text-center text-md-start">
#       This website is not directly or indirectly affiliated, associated, or connected in any way to Major League Baseball, the National Basketball Association, the National Football League or the National Hockey League. Use of any marks, trademarks, or logos on this website shall not constitute a sponsorship or endorsement by the trademark holder.
#      </div>
#     </div>
#    </div>
#   </footer>
#   <div class="position-fixed top-0 start-50 translate-middle-x p-3" style="z-index: 11">
#    <div aria-atomic="true" aria-live="assertive" class="toast" id="table-copied-toast" role="alert">
#     <div class="toast-header bg-info text-white">
#      <strong class="me-auto">
#       Copied!
#      </strong>
#      <button aria-label="Close" class="btn-close text-white" data-bs-dismiss="toast" type="button">
#      </button>
#     </div>
#     <div class="toast-body">
#      Table has been copied!
#     </div>
#    </div>
#   </div>
#   <!-- Back To Top Button-->
#   <a class="btn-scroll-top" data-scroll="" href="#top">
#    <span class="btn-scroll-top-tooltip text-muted fs-sm me-2">
#     Top
#    </span>
#    <i class="btn-scroll-top-icon ci-arrow-up">
#    </i>
#   </a>
#   <!-- Vendor scrits: js libraries and plugins-->
#   <script src="https://www.spotrac.com/public/vendor/bootstrap/dist/js/bootstrap.bundle.min.js">
#   </script>
#   <script src="https://www.spotrac.com/public/vendor/simplebar/dist/simplebar.min.js">
#   </script>
#   <script src="https://www.spotrac.com/public/vendor/tiny-slider/dist/min/tiny-slider.js">
#   </script>
#   <script src="https://www.spotrac.com/public/vendor/smooth-scroll/dist/smooth-scroll.polyfills.min.js">
#   </script>
#   <script src="https://www.spotrac.com/public/vendor/jquery.doubleScroll/jquery.doubleScroll.js">
#   </script>
#   <script src="https://www.spotrac.com/public/vendor/table2csv/table2csv.min.js">
#   </script>
#   <script src="https://www.spotrac.com/public/vendor/tablesorter/jquery.tablesorter.min.js">
#   </script>
#   <script src="https://www.spotrac.com/public/vendor/clipboard/clipboard.min.js">
#   </script>
#   <script src="https://www.spotrac.com/public/vendor/imagesloaded/imagesloaded.pkgd.min.js">
#   </script>
#   <script src="https://www.spotrac.com/public/vendor/shufflejs/dist/shuffle.min.js">
#   </script>
#   <script src="https://www.spotrac.com/public/vendor/jquery.mousewheel/jquery.mousewheel.min.js">
#   </script>
#   <!-- Main theme script-->
#   <script src="https://www.spotrac.com/public/js/theme.js">
#   </script>
#   <!-- Additional theme script-->
#   <script src="https://www.spotrac.com/public/js/theme-custom.js">
#   </script>
#   <!-- GA4 -->
#   <!-- Page specific script-->
#   <script>
#    // FILTER
#
# $(document).on("change", "form#filter input", function(){
#
#     $("#filtering").removeClass("d-none");
#
#     var reference_id = $(this).data("reference");
#
#     if($(this).is(":checked"))
#     {
#         $("input#"+reference_id+"_reference1").prop("checked",true).attr("checked",true);
#         $("input#"+reference_id+"_reference2").prop("checked",true).attr("checked",true);
#     }
#     else
#     {
#         $("input#"+reference_id+"_reference1").prop("checked",false).attr("checked",false);
#         $("input#"+reference_id+"_reference2").prop("checked",false).attr("checked",false);
#     }
#
#     //
#
#     run_filter()
#
# })
#
# $(document).on("change", "form#filter select", function(){
#
#     $("#filtering").removeClass("d-none");
#
#     //
#
#     run_filter()
#
# })
#
# $(document).on("click", "a.breadcrumb", function(){
#
#     $("#filtering").removeClass("d-none");
#
#     var reference_id = $(this).data("reference");
#
#     $("input#"+reference_id+"_reference1").prop("checked",false).attr("checked",false);
#     $("input#"+reference_id+"_reference2").prop("checked",false).attr("checked",false);
#
#     if($(this).parents("li").find("a").length==1)
#     {
#         $(this).parents("li").remove();
#     }
#
#     $(this).remove();
#
#     //
#
#     run_filter()
#
# })
#
# // RESET FILTER
#
# $(document).on("click", ".reset", function(e){
#
#     e.preventDefault();
#
#
#     $(".filtering-overlay").removeClass("d-none");
#
#     $("table").addClass("blur")
#
#     //
#
#     document.location.href = 'https://www.spotrac.com/mlb/rankings/player'
#
# });
#
# // SORT
#
# $(document).on("click", "th.sort", function(){
#
#     $("form#filter input[name='sort']").val( $(this).data('sort') );
#
#     //
#
#     run_filter()
#
# });
#
# function run_filter()
# {
#     //$("#filtering-icon").removeClass("d-none");
#     $(".filtering-overlay").removeClass("d-none");
#
#     //
#
#     var nextURL = $("form#filter").data('action');
#
#     var selections = $("form#filter").serializeArray();
#
#     var params = [];
#     var year_exists = false;
#
#     for(var i=0; i<selections.length; i++)
#     {
#         if(selections[i].name=='year')
#         {
#             year_exists = selections[i].value;
#         }
#     }
#
#     if(!year_exists)
#     {
#         params['year'] = [];
#         params['year'].push( 2024 );
#     }
#
#     for(var i=0; i<selections.length; i++)
#     {
#         if(selections[i].name=='sort')
#         {
#             params['sort'] = [];
#             params['sort'].push( selections[i].value );
#         }
#         else if(selections[i].name!='sort' && selections[i].value!='')
#         {
#             if(!params[ selections[i].name ])
#             {
#                 params[selections[i].name] = [];
#             }
#
#             params[selections[i].name].push( selections[i].value );
#         }
#     }
#
#
#
#     var params_str = '';
#     for (var key in params)
#     {
#         var value = params[key];
#
#         params_str += '/'+key+'/'+value.join("+");
#     }
#
#      nextURL = nextURL+'/_'+params_str;
#
#
#     $("ul.list-group").addClass("blur")
#     $("table").addClass("blur")
#
#     $.ajax({
#         type: 'post',
#         url: nextURL,
#         data: 'ajax=table',
#         success: function(data){
#             $("#table-wrapper").html(data)
#
#             init_table_scrolling();
#         }
#     });
#
#
# 	// update url history
#     window.history.pushState({href: nextURL}, '', nextURL);
# }
#
# $("#csv-export").click(function(){
#
#     $("table#table").table2csv('download', {filename: "mlb-rankings-player.csv"});
#
# })
#
#
# // HIDE FILTER BASED ON VIEW
#
# if ($(window).width() < 700)
# {
#     $("#filter-desktop").remove();
# }
# else if ($(window).width() >= 700)
# {
#     $("#filter-mobile").remove();
# }
#   </script>
#  </body>
# </html>

# %%
contract_values_urls = [
    url11,
    url12,
    url13,
    url14,
    url15,
    url16,
    url17,
    url18,
    url19,
    url20
]

def add_contract_value_data(df, urls):
    for url in urls:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.text, 'html.parser')
            # Adjust the selector based on the detailed HTML structure provided
            player_entries = soup.select('body main > div:nth-of-type(2) section div div div section article > div:nth-of-type(3) > div:nth-of-type(2) > div > ul > li')

            for entry in player_entries:
                # Extract player name from the current 'li' element
                player_name = entry.select_one('span a div div').text.strip() if entry.select_one('span a div div') else None

                if player_name:
                    # Check against all players in the DataFrame
                    for i, df_player in df.iterrows():
                        if df_player['PlayerName'].strip() == player_name:
                            # Extract the contract value
                            contract_value_element = entry.select('li span')[1] if len(entry.select('li span')) > 1 else None
                            contract_value = contract_value_element.text.strip() if contract_value_element else 'Value not found'

                            # Update the DataFrame
                            df.at[i, 'ContractValue'] = contract_value
                            break  # Stop searching once a match is found
        else:
            print(f"Failed to retrieve data from {url}")

    return df

# Assuming contract_values_urls is already defined with your specific URLs
contracts_df = add_contract_value_data(contracts_df, contract_values_urls)
contracts_df.at[0, 'ContractValue'] = '$140,000,000'

# Display the updated DataFrame
print(contracts_df)
# Out:
#              PlayerName PlayerTeam PlayerPosition ContractLength ContractValue
# 0            Will Smith        LAD              C             10  $140,000,000
# 1          Keibert Ruiz        WSH              C              8   $50,000,000
# 2           Sean Murphy        ATL              C              6   $73,000,000
# 3     Willson Contreras        STL              C              5   $87,500,000
# 4         J.T. Realmuto        PHI              C              5  $115,500,000
# 5          Bryce Harper        PHI             1B             13  $330,000,000
# 6            Matt Olson        ATL             1B              8  $168,000,000
# 7      Jake Cronenworth         SD             1B              7   $80,000,000
# 8           Kris Bryant        COL             1B              7  $182,000,000
# 9       Freddie Freeman        LAD             1B              6  $162,000,000
# 10      Xander Bogaerts         SD             2B             11  $280,000,000
# 11          Jose Altuve        HOU             2B              7  $163,500,000
# 12       Andres Gimenez        CLE             2B              7  $106,500,000
# 13        Marcus Semien        TEX             2B              7  $175,000,000
# 14         Ozzie Albies        ATL             2B              7   $35,000,000
# 15        Rafael Devers        BOS             3B             10  $313,500,000
# 16         Austin Riley        ATL             3B             10  $212,000,000
# 17       Ke'Bryan Hayes        PIT             3B              8   $70,000,000
# 18        Nolan Arenado        STL             3B              8  $260,000,000
# 19         José Ramírez        CLE             3B              7  $141,000,000
# 20         Mookie Betts        LAD             SS             12  $365,000,000
# 21        Wander Franco         TB             SS             11  $182,000,000
# 22       Bobby Witt Jr.         KC             SS             11  $288,777,777
# 23          Trea Turner        PHI             SS             11  $300,000,000
# 24         Corey Seager        TEX             SS             10  $325,000,000
# 25   Fernando Tatis Jr.         SD             RF             14  $340,000,000
# 26      Jackson Chourio        MIL             RF              8   $82,000,000
# 27     Ronald Acuña Jr.        ATL             RF              8  $100,000,000
# 28       Bryan Reynolds        PIT             RF              8  $106,750,000
# 29       Corbin Carroll        ARI             RF              8  $111,000,000
# 30           Mike Trout        LAA             CF             12  $426,500,000
# 31      Julio Rodriguez        SEA             CF             12  $209,300,000
# 32          Aaron Judge        NYY             CF              9  $360,000,000
# 33    Michael Harris II        ATL             CF              8   $72,000,000
# 34     Ceddanne Rafaela        BOS             CF              8   $50,000,000
# 35        Brandon Nimmo        NYM             LF              8  $162,000,000
# 36     Christian Yelich        MIL             LF              7  $188,500,000
# 37       Yordan Alvarez        HOU             LF              6  $115,000,000
# 38    Andrew Benintendi        CHW             LF              5   $75,000,000
# 39  Lourdes Gurriel Jr.        ARI             LF              3   $42,000,000
# 40   Yoshinobu Yamamoto        LAD             SP             12  $325,000,000
# 41        Shohei Ohtani        LAD             SP             10  $700,000,000
# 42          Gerrit Cole        NYY             SP              9  $324,000,000
# 43         Jose Berrios        TOR             SP              7  $131,000,000
# 44           Aaron Nola        PHI             SP              7  $172,000,000
# 45    Giancarlo Stanton        NYY             DH             13  $325,000,000
# 46        Manny Machado         SD             DH             11  $350,000,000
# 47         Eloy Jimenez        CHW             DH              6   $43,000,000
# 48     Nick Castellanos        PHI             DH              5  $100,000,000
# 49     Masataka Yoshida        BOS             DH              5   $90,000,000

# %%
# save df to a csv file
contracts_df.to_csv('contract_info.csv', index=False)

# %%
def create_db_engine(user, password, host, port, database):
    return create_engine(f'mysql+mysqldb://{user}:{password}@{host}:{port}/{database}')

# %%
#load CSV into DataFrame
def load_csv(file_path):
    return pd.read_csv(file_path)

# %%
# Function to upload DataFrame to MySQL
def upload_to_mysql(df, engine, table_name):
    df.to_sql(name=table_name, con=engine, if_exists='append', index=False, chunksize=500)

# %%
# Main script execution
if __name__ == "__main__":
    # Database credentials and connection details
    USER = 'admin'
    PASSWORD = 'isba_4798'
    HOST = 'isba-dev-01.c7eifmhfznoo.us-east-1.rds.amazonaws.com'
    PORT = '3306'
    DATABASE = 'sql_project'
    TABLE_NAME = 'contract_values'

    # Path to the CSV file
    CSV_FILE_PATH = '/content/contract_info.csv'

    # Create a database engine
    engine = create_db_engine(USER, PASSWORD, HOST, PORT, DATABASE)

    # Load data from CSV
    dataframe = load_csv(CSV_FILE_PATH)

    # Upload data to MySQL
    upload_to_mysql(dataframe, engine, TABLE_NAME)
    print("CSV data has been uploaded successfully to MySQL!")
# Out:
# CSV data has been uploaded successfully to MySQL!
